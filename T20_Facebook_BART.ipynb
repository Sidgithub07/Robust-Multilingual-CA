# %%
import pandas as pd
from transformers import pipeline
from sklearn.metrics import accuracy_score

# Load the CSV file (assuming the file has a 'label' column with ground truth labels)
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/T20_WorldCup/T20_cleaned_comments.csv')
tot_count = len(df['all_eng'])

# Initialize the zero-shot classification pipeline
classifier = pipeline(
    task="zero-shot-classification",
    model="facebook/bart-large-mnli"
)

comment_list = []
sentiment_list = []


# Lists to hold predicted labels and true labels
predicted_labels = []
true_labels = df['label'].tolist() if 'label' in df.columns else None  # Ground truth labels, if available

# Sentiment count dictionary to summarize sentiment distribution
sentiment_counts = {'positive': 0, 'negative': 0, 'neutral': 0}

# Define the candidate labels for classification
candidate_labels = ["positive", "negative", "neutral"]

# Loop through each comment in the DataFrame, classify, and gather results
for comment in df['all_eng']:
    # Classify the comment using zero-shot classification
    result = classifier(comment, candidate_labels, multi_label=True)

    # Get the label with the highest score
    predicted_label = result['labels'][result['scores'].index(max(result['scores']))]
    predicted_labels.append(predicted_label)

    # Count the sentiment type for summary
    sentiment_counts[predicted_label] += 1

    comment_list.append(comment)
    sentiment_list.append(predicted_label)

    # Optional: Print the original comment and predicted sentiment
    print(f"Original Comment: {comment}")
    print(f"Predicted Sentiment: {predicted_label}")
    print()

# Calculate sentiment percentages for each category
total_comments = len(df['all_eng'])
percent_positive = (sentiment_counts['positive'] / total_comments) * 100
percent_negative = (sentiment_counts['negative'] / total_comments) * 100
percent_neutral = (sentiment_counts['neutral'] / total_comments) * 100

# Print the overall sentiment summary
print(f"Overall Sentiment of Comments:")
print(f"Positive: {percent_positive:.2f}%")
print(f"Negative: {percent_negative:.2f}%")
print(f"Neutral: {percent_neutral:.2f}%")

# Calculate accuracy if true labels are provided
if true_labels is not None:
    accuracy = accuracy_score(true_labels, predicted_labels)
    print(f"Accuracy of the model: {accuracy * 100:.2f}%")
else:
    print("No ground truth labels found for accuracy calculation.")

dict = {'Cleaned_Comment': comment_list,
        'Predicted_Sentiment': sentiment_list,}

df_new = pd.DataFrame(dict)
#df_new.to_csv('final_output.csv', index=False)

df_new.to_csv('/content/drive/MyDrive/Colab Notebooks/T20WC_final_facebook.csv', index=False)
df_new
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Device set to use cuda:0
# Original Comment: watching today
# Predicted Sentiment: positive
#
# Original Comment: sa donated the cup to india these sa players cannot break the shackles of a choker tag
# Predicted Sentiment: negative
#
# Original Comment: i am crying
# Predicted Sentiment: negative
#
# Original Comment: uff the commentary is at its best
# Predicted Sentiment: positive
#
# Original Comment: forever india
# Predicted Sentiment: positive
#
# Original Comment: one of the most memorable final match ever
# Predicted Sentiment: positive
#
# Original Comment: epic final catch amp match ever
# Predicted Sentiment: positive
#
# Original Comment: what to typei dont know hoping for the champions trophy now
# Predicted Sentiment: positive
#
# Original Comment: came back to see that catch by surya
# Predicted Sentiment: positive
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Streaming output truncated to the last 5000 lines.
# Original Comment: sach me rona to rukh hi nehi raha he jai hind
# Predicted Sentiment: negative
#
# Original Comment: kaun kaun hardik pandya ko maaf kar chuke ho like kare
# Predicted Sentiment: negative
#
# Original Comment: yes sir
# Predicted Sentiment: positive
#
# Original Comment: thnku king kohli
# Predicted Sentiment: positive
#
# Original Comment: india ke agi koi jeet sakta hai kya
# Predicted Sentiment: positive
#
# Original Comment: love rohit
# Predicted Sentiment: positive
#
# Original Comment: blkl indai ur the bast team end i love india or indain team congratulations my indian brothers koli i miss you
# Predicted Sentiment: positive
#
# Original Comment: hardik dikh gya jaspreet dikh gya arsh ka pta nhi kisi ko
# Predicted Sentiment: negative
#
# Original Comment: congratulations indian brother from pakistan
# Predicted Sentiment: positive
#
# Original Comment: please sir kise ke upar khami mat nikaliye ga
# Predicted Sentiment: positive
#
# Original Comment: is this match fix do you agree
# Predicted Sentiment: negative
#
# Original Comment: bumrah ka statue lgana chahiye kon kon chahta hai
# Predicted Sentiment: negative
#
# Original Comment: sach me rona aa gaya yaar cricket fan hona koi mamuli baat nahi
# Predicted Sentiment: positive
#
# Original Comment: yaar koi arshdeep singh ka naam kyu nhi leta usne jo kiya woh km tha kiya yaar koi to credit dao arshdeep singh ko
# Predicted Sentiment: positive
#
# Original Comment: surya ka catch bht important tha
# Predicted Sentiment: positive
#
# Original Comment: mai khus nahi hu virat ke retire hone pe kyuki mai match hi virat kohli ke liye dekhta hu
# Predicted Sentiment: negative
#
# Original Comment: aaj ke baad koi sky pe doubt nehi kar payega
# Predicted Sentiment: negative
#
# Original Comment: sir i love my team india and i love my india
# Predicted Sentiment: positive
#
# Original Comment: love you indian cricket team
# Predicted Sentiment: positive
#
# Original Comment: indian player is the best in the world
# Predicted Sentiment: positive
#
# Original Comment: best bowler in the world jasprit bumrah respect button
# Predicted Sentiment: positive
#
# Original Comment: india win the world cup form nepal
# Predicted Sentiment: positive
#
# Original Comment: surya jo rat mein chamkta hai
# Predicted Sentiment: negative
#
# Original Comment: hardik pandeya ko jo boo boo kar rahe wahi aaj match jitaya ab hardik pandeya ki respect krooo
# Predicted Sentiment: negative
#
# Original Comment: south africa is unlucky team since decades whether klusner or klason will be there
# Predicted Sentiment: negative
#
# Original Comment: mera dil kasamse me itna khush ku k yesa laga nepal world cup jitgya
# Predicted Sentiment: positive
#
# Original Comment: sir ham roaai aa gaaa hai
# Predicted Sentiment: negative
#
# Original Comment: mishra sir mein to ro ro ke asha chhod dia tha
# Predicted Sentiment: negative
#
# Original Comment: i am so sad virat sir announced retirement we are never forget your contribution
# Predicted Sentiment: negative
#
# Original Comment: rohit the king of kings
# Predicted Sentiment: positive
#
# Original Comment: thanks today prauod moment indian all
# Predicted Sentiment: positive
#
# Original Comment: aaj ke koi v kabhi hitman ke captaincy pe doubt karne ka himmat nehi karega
# Predicted Sentiment: negative
#
# Original Comment: mai to rone lga lga tha bhagwan se pray kiyaor god ne sun liwe are champion
# Predicted Sentiment: positive
#
# Original Comment: selfish old rohit dint announce retirement
# Predicted Sentiment: negative
#
# Original Comment: ajj india ka din tha
# Predicted Sentiment: positive
#
# Original Comment: im very happy from kashmir i love my team congratulations team india
# Predicted Sentiment: positive
#
# Original Comment: we all proud of you king and hitman both
# Predicted Sentiment: positive
#
# Original Comment: hamara virat ne khushi ke sath dukhi ka ansu bhi de gaye
# Predicted Sentiment: negative
#
# Original Comment: mujhe lgta tha ki jeet ke khushi mein sirf main ro raha hun magar abhi dekh liya shubhankar sir aap bhi ro rahe ho
# Predicted Sentiment: negative
#
# Original Comment: i miss you king kohli
# Predicted Sentiment: negative
#
# Original Comment: gusbumps ara hai
# Predicted Sentiment: positive
#
# Original Comment: apka video facebook me nhi mila isliye youtube pe aaya
# Predicted Sentiment: positive
#
# Original Comment: hitman sharma
# Predicted Sentiment: positive
#
# Original Comment: congratulations to everyone
# Predicted Sentiment: positive
#
# Original Comment: heart in hit hardik pandya
# Predicted Sentiment: positive
#
# Original Comment: rohait sharma best captain in world
# Predicted Sentiment: positive
#
# Original Comment: surya and bumra and virat u r the king
# Predicted Sentiment: positive
#
# Original Comment: yaar please never criticise your national team
# Predicted Sentiment: negative
#
# Original Comment: indian indian indian indian
# Predicted Sentiment: positive
#
# Original Comment: congratulation ap ko bhi bharat mata ki jai
# Predicted Sentiment: positive
#
# Original Comment: im big fan of rohit
# Predicted Sentiment: positive
#
# Original Comment: hardik ne klasen ka wikt lekar match ko jitya hai
# Predicted Sentiment: negative
#
# Original Comment: aaj to shubham dube ne bhi
# Predicted Sentiment: negative
#
# Original Comment: congratulations india team and indian nation from iran
# Predicted Sentiment: positive
#
# Original Comment: congratulations jay hind all friends
# Predicted Sentiment: positive
#
# Original Comment: virat axal pandya arsh bumrah suriya
# Predicted Sentiment: positive
#
# Original Comment: mom kohli ko backdrop me jagah bhi nhi
# Predicted Sentiment: negative
#
# Original Comment: r s f
# Predicted Sentiment: negative
#
# Original Comment: india huge amounts of rupees invest in cricket so india ko world cup jeetna chahea so india won love you indian team deserve world cup
# Predicted Sentiment: positive
#
# Original Comment: shandaar match i proud of indian team
# Predicted Sentiment: positive
#
# Original Comment: i love you all
# Predicted Sentiment: positive
#
# Original Comment: virat kholi all time best
# Predicted Sentiment: positive
#
# Original Comment: jis khilaadee ko poora ipl booo boooo kar raha tha usee ne varld kap jita diya congratulation to india well played south africa
# Predicted Sentiment: positive
#
# Original Comment: main bohut duwa kari sir rohit amp virat kohli show today
# Predicted Sentiment: positive
#
# Original Comment: mujhe mere desh ki team pe garv h jai hind
# Predicted Sentiment: positive
#
# Original Comment: yuvraj singh arshdeep singh
# Predicted Sentiment: positive
#
# Original Comment: congress rohit sharma and all team india
# Predicted Sentiment: positive
#
# Original Comment: viratttttttttttttttt
# Predicted Sentiment: negative
#
# Original Comment: hum sabko badhai
# Predicted Sentiment: negative
#
# Original Comment: klasen but finally we win
# Predicted Sentiment: positive
#
# Original Comment: all ind team
# Predicted Sentiment: positive
#
# Original Comment: surya kumar catch nehi world cup pakra tha
# Predicted Sentiment: positive
#
# Original Comment: bap bap hota hai congratulations
# Predicted Sentiment: positive
#
# Original Comment: i cried a lot today the tears of joy dont want to stop love you team india miss you the great legend of virat kohli
# Predicted Sentiment: positive
#
# Original Comment: hame pata hai india jeeta hai
# Predicted Sentiment: positive
#
# Original Comment: auj se cricket dehkna band viraat king ritayarment ke shath shath mene bhi cricket ko dehkne se ritayarment le li i miss you mere king virat my hero i miss u
# Predicted Sentiment: positive
#
# Original Comment: cheekh cheekh ke gala baith chuka hai
# Predicted Sentiment: positive
#
# Original Comment: kismat rohit ki lakky
# Predicted Sentiment: negative
#
# Original Comment: bhai ab to dono hi nhi khelenge world cup
# Predicted Sentiment: positive
#
# Original Comment: mishra ji hum world cup win kar gaye congratulations apko
# Predicted Sentiment: positive
#
# Original Comment: me kahi spna to nhi dekh rhe
# Predicted Sentiment: negative
#
# Original Comment: ro ko boom hardik adp sky ap kd db rp rj
# Predicted Sentiment: positive
#
# Original Comment: surya miller catch match
# Predicted Sentiment: positive
#
# Original Comment: hardik is proven again that he is a quality allrounder
# Predicted Sentiment: positive
#
# Original Comment: hitman best captain indian team
# Predicted Sentiment: positive
#
# Original Comment: congress india
# Predicted Sentiment: positive
#
# Original Comment: is bar afford nhi kr pate hum
# Predicted Sentiment: negative
#
# Original Comment: bro mai tha india always won
# Predicted Sentiment: positive
#
# Original Comment: sidhu was saying bumrah koi bhagwan nhi h jo match ko palat dega but
# Predicted Sentiment: negative
#
# Original Comment: surya kumar yadav ke catch ki wajah se india match jeeta
# Predicted Sentiment: positive
#
# Original Comment: i love youindia
# Predicted Sentiment: positive
#
# Original Comment: sbroapkchanlkmadhamsafualaenjayjomelahaapkalefualmatharanisetarathanahakekhushrahigoodnihteisakajabjarudeokbroapkajabkaenajrakaragejayshreeramsuhanlala
# Predicted Sentiment: positive
#
# Original Comment: bhai dubey ji ko ise pahle wali video me bahot dhoya tha aapne kam se kam aaj acha khela usne uska bhi naam le lete aaj
# Predicted Sentiment: negative
#
# Original Comment: aaj dil se anshu nhi ruk rhe the world champion
# Predicted Sentiment: positive
#
# Original Comment: saan hai maan hai india ka jaan hai king kohli
# Predicted Sentiment: positive
#
# Original Comment: kya match tha yar
# Predicted Sentiment: positive
#
# Original Comment: arshdeep singh is king
# Predicted Sentiment: positive
#
# Original Comment: ki baat kyu nai
# Predicted Sentiment: negative
#
# Original Comment: nepali but i will always support india
# Predicted Sentiment: positive
#
# Original Comment: many many congratulations team india
# Predicted Sentiment: positive
#
# Original Comment: thanks mba chaiwala
# Predicted Sentiment: positive
#
# Original Comment: sr aaj bahut bahut khus hu apney king kohli ke ley
# Predicted Sentiment: negative
#
# Original Comment: sir arshdeep
# Predicted Sentiment: positive
#
# Original Comment: yishu masih ne prathna ko suna hai
# Predicted Sentiment: negative
#
# Original Comment: surya kumar fields bhumra bowling virat batting man of match
# Predicted Sentiment: positive
#
# Original Comment: miss you legend virat kohli
# Predicted Sentiment: negative
#
# Original Comment: thank u india thank u to the entire indian team
# Predicted Sentiment: positive
#
# Original Comment: arshdeep kahaan gya
# Predicted Sentiment: positive
#
# Original Comment: congratulations sabhi bhartiyo ko
# Predicted Sentiment: positive
#
# Original Comment: naya ladka se make do
# Predicted Sentiment: positive
#
# Original Comment: jeeta gaye ham sir aj to dil garden garden ho gaya
# Predicted Sentiment: positive
#
# Original Comment: abe yaar tu bhi in porkion ki tarah nikla kya duwa buwa karta hai india apne dum par jita hai aur rahegasamje chaar aankhon wale
# Predicted Sentiment: negative
#
# Original Comment: sr me saudi arabia me rahta hu aap ke aawaj suney nina nid nahi aati
# Predicted Sentiment: negative
#
# Original Comment: yaar sach maano to ye match ko suriya kumar yadav ne catch pakad ke jitaya
# Predicted Sentiment: positive
#
# Original Comment: virat retirement
# Predicted Sentiment: negative
#
# Original Comment: agali bar champions trophy mein bhi jalva dikhana hai
# Predicted Sentiment: positive
#
# Original Comment: very nice information boss thanks
# Predicted Sentiment: positive
#
# Original Comment: kasam se bahut dua magi
# Predicted Sentiment: positive
#
# Original Comment: hardik pandya ke naam se paisa chapne wala brainless journalist in india
# Predicted Sentiment: negative
#
# Original Comment: klassen wicket waaav hardik pandya u took wicket
# Predicted Sentiment: negative
#
# Original Comment: respect rahul dravid and all team
# Predicted Sentiment: positive
#
# Original Comment: for rohit amp virat like
# Predicted Sentiment: positive
#
# Original Comment: south africa ne sabit kar diya ki wo chokash h the our rahenge
# Predicted Sentiment: negative
#
# Original Comment: iski bhn ki maze maze india win
# Predicted Sentiment: positive
#
# Original Comment: puri team acha kheli maja aa gya
# Predicted Sentiment: positive
#
# Original Comment: jis hardik pandya ko log ipl k waqt na jaane kya kya gaali diya aaj wohi hardik pandya ne klassen ki wicket lekar match he badal diyai also literally cried when hardik finished his over what a bowling performance in last five overs by all bowlers and throughout the tournament our guys played like a championlet us celebrate this win and forget everything
# Predicted Sentiment: positive
#
# Original Comment: ha sir ham jeet gye
# Predicted Sentiment: positive
#
# Original Comment: aaj to dil hi baith jata congratulations hitman congratulations champion
# Predicted Sentiment: positive
#
# Original Comment: ham hai
# Predicted Sentiment: positive
#
# Original Comment: hm durga mata se prathana ki thi indian jit jay mata rani ne sun liya jay mata di
# Predicted Sentiment: positive
#
# Original Comment: congratulations team india love you pure hindustani ko jeet ki badhi ho
# Predicted Sentiment: positive
#
# Original Comment: welcome india and congratulations
# Predicted Sentiment: positive
#
# Original Comment: india desirve world cup
# Predicted Sentiment: positive
#
# Original Comment: but yar sa ka bhi dukh mahsus ho raha hai
# Predicted Sentiment: negative
#
# Original Comment: har har mahadev prabhu ki kripa se sab sambhav hai
# Predicted Sentiment: positive
#
# Original Comment: virat kohli ne jitaaya hai
# Predicted Sentiment: negative
#
# Original Comment: my hart india
# Predicted Sentiment: positive
#
# Original Comment: congratulations jay hind jay shri ram
# Predicted Sentiment: positive
#
# Original Comment: sauth afrika iindia
# Predicted Sentiment: positive
#
# Original Comment: sir aap ka dil nahi tuta hardik is future captain rohit is baap of all captain v
# Predicted Sentiment: positive
#
# Original Comment: sab chahte hai
# Predicted Sentiment: positive
#
# Original Comment: suryakumar yadav ne wc pakad lia
# Predicted Sentiment: negative
#
# Original Comment: each and every player is good
# Predicted Sentiment: positive
#
# Original Comment: rit
# Predicted Sentiment: negative
#
# Original Comment: rohit sharma best captain all the best boom boom bomrah king kholi
# Predicted Sentiment: positive
#
# Original Comment: the match winning movement was the henry klasscen wicket
# Predicted Sentiment: positive
#
# Original Comment: par hamne nhi dakh pya for protection our country
# Predicted Sentiment: positive
#
# Original Comment: speechlesstears in eays
# Predicted Sentiment: negative
#
# Original Comment: aj angry rantman zinda hota to kitna acca hota miss you bro
# Predicted Sentiment: negative
#
# Original Comment: sach me
# Predicted Sentiment: positive
#
# Original Comment: odi wicket
# Predicted Sentiment: negative
#
# Original Comment: king kohli may hero today retired
# Predicted Sentiment: positive
#
# Original Comment: goti muh me aa gya tha classan jit tarah maar rha tha
# Predicted Sentiment: positive
#
# Original Comment: hardik deserve
# Predicted Sentiment: positive
#
# Original Comment: thank you for rohit sharma final win final
# Predicted Sentiment: positive
#
# Original Comment: bhai pali bar ik cup geetna tha south africa ko
# Predicted Sentiment: positive
#
# Original Comment: bhut roye aaj dil khush h
# Predicted Sentiment: negative
#
# Original Comment: east or west rahul is the best team india
# Predicted Sentiment: positive
#
# Original Comment: virat dhoni n the hitman rohit
# Predicted Sentiment: negative
#
# Original Comment: ye surya kumar yadav ki catch hum kabhi nhi bhool payenge or viratkohli hum hmesha apko yaad rakhenge love u bumrah love u what are man rohit sharma apne hame ye din dia hai
# Predicted Sentiment: positive
#
# Original Comment: but main kyu ro ra hu
# Predicted Sentiment: negative
#
# Original Comment: koi v hardik ko replace nhi kr skta h hardik champion player h
# Predicted Sentiment: positive
#
# Original Comment: pandya gumrah bumra surya namaskar postures for catch
# Predicted Sentiment: positive
#
# Original Comment: jake pandya se mafi mang
# Predicted Sentiment: negative
#
# Original Comment: ro ko on top
# Predicted Sentiment: positive
#
# Original Comment: congratulations team india we are proud you
# Predicted Sentiment: positive
#
# Original Comment: india fans like here
# Predicted Sentiment: positive
#
# Original Comment: ye lambe samay tak yaad kiya jayega
# Predicted Sentiment: negative
#
# Original Comment: congratulations team india from ireland
# Predicted Sentiment: positive
#
# Original Comment: dukh hota hai bhai log hardik ko credit bhi dena chate jabki jante hai klassen ne kitna koota hai
# Predicted Sentiment: negative
#
# Original Comment: who doub indian performance are fuck off
# Predicted Sentiment: negative
#
# Original Comment: aaj to surya ne kamal kr diya
# Predicted Sentiment: negative
#
# Original Comment: i love u india
# Predicted Sentiment: positive
#
# Original Comment: i love my india virat kohli super se bhi upar h bhai
# Predicted Sentiment: positive
#
# Original Comment: ro hitman sharma respect button
# Predicted Sentiment: positive
#
# Original Comment: mba south africa
# Predicted Sentiment: positive
#
# Original Comment: yehi log hai jo hardik ko chhapri chhapri bol rahi thi saalon dikha diya na mere chhapri ne apna kamal love u again hardik
# Predicted Sentiment: positive
#
# Original Comment: pandya deserve more respect
# Predicted Sentiment: positive
#
# Original Comment: ye wese hi scenario tha jese catch match jeet gye the
# Predicted Sentiment: positive
#
# Original Comment: virat fan like here
# Predicted Sentiment: positive
#
# Original Comment: congratulations team india win the
# Predicted Sentiment: positive
#
# Original Comment: we always miss you king
# Predicted Sentiment: negative
#
# Original Comment: jai hind jai rohit
# Predicted Sentiment: negative
#
# Original Comment: hardik ke hetrs khahe bhi
# Predicted Sentiment: negative
#
# Original Comment: sir congratulations aap ko aap bahut aaxa ensan he love u from nepal
# Predicted Sentiment: positive
#
# Original Comment: jai ho team india
# Predicted Sentiment: positive
#
# Original Comment: bumrah ki bowling ke vajah se match jita gaya
# Predicted Sentiment: positive
#
# Original Comment: hardik ko badhai ho sala chhichora log hardik ko chhapri keheke bolaya lekin hero toh wo huwa
# Predicted Sentiment: negative
#
# Original Comment: congratulations to all finally we have cup
# Predicted Sentiment: positive
#
# Original Comment: congratulation india love from pakistan sad for vk retirement
# Predicted Sentiment: positive
#
# Original Comment: chakde india
# Predicted Sentiment: positive
#
# Original Comment: hhhhhhhhhhhhhhhh
# Predicted Sentiment: negative
#
# Original Comment: puri team ki efforts hai
# Predicted Sentiment: positive
#
# Original Comment: bcci ko puri economy lgaa deni chahiye bumrah ki copy tyaar krne mvrnaa hmaraa kya hoga bumrah k baad i m scared of this country k har chowk pr jaspreet ka statue lgvaado pride of india bharat ratna dedo bumrah bhai
# Predicted Sentiment: negative
#
# Original Comment: we are proud
# Predicted Sentiment: positive
#
# Original Comment: king kohli ke pari kisko achchhi lagi hai
# Predicted Sentiment: positive
#
# Original Comment: its not just indias pride its asias pride tears are coming to the eyes unknowingly congratulations india team
# Predicted Sentiment: positive
#
# Original Comment: team india champion but team africa well played
# Predicted Sentiment: positive
#
# Original Comment: bumrah is the best bowler
# Predicted Sentiment: positive
#
# Original Comment: sare jahan se achha hindu sita hamara
# Predicted Sentiment: negative
#
# Original Comment: jay shriram
# Predicted Sentiment: positive
#
# Original Comment: ham nepal se hai lekin aaj indian jaise kar raha tha
# Predicted Sentiment: negative
#
# Original Comment: virat kohli ko abhi retirement nhi lena chahiye
# Predicted Sentiment: negative
#
# Original Comment: i love
# Predicted Sentiment: positive
#
# Original Comment: rohit sharma amp virat kohli please dont retire
# Predicted Sentiment: positive
#
# Original Comment: i love you rohit sir
# Predicted Sentiment: positive
#
# Original Comment: saans phula roya v arr khusii
# Predicted Sentiment: positive
#
# Original Comment: surya bhai really hero
# Predicted Sentiment: positive
#
# Original Comment: tula maanla re bhauu surya
# Predicted Sentiment: positive
#
# Original Comment: same match nepal vs southafrica vs south africa
# Predicted Sentiment: neutral
#
# Original Comment: pahali bar cricket ke liye roye
# Predicted Sentiment: negative
#
# Original Comment: aaj india built different hogyi hai
# Predicted Sentiment: positive
#
# Original Comment: ham khub rovani bhai
# Predicted Sentiment: positive
#
# Original Comment: biggest fan of hardik and virat
# Predicted Sentiment: positive
#
# Original Comment: king is always king king virat kohli
# Predicted Sentiment: positive
#
# Original Comment: arshdeep good bowling
# Predicted Sentiment: positive
#
# Original Comment: dubey also didnt disappoint today it was a good cameo he will get better
# Predicted Sentiment: positive
#
# Original Comment: wo catch hi game changer tha by surya
# Predicted Sentiment: positive
#
# Original Comment: oh my god kitna thirral match thafinnally india win world cup love you team india congratulations team india
# Predicted Sentiment: positive
#
# Original Comment: bapu ka badala le liya
# Predicted Sentiment: negative
#
# Original Comment: woo catch nahi match winning movement tha
# Predicted Sentiment: positive
#
# Original Comment: vo suryakumar yadav ka catch hona or india ki jeet ka sunishchit hona maja a gya very big congratulations team india
# Predicted Sentiment: positive
#
# Original Comment: congratulations team india hitman i love you
# Predicted Sentiment: positive
#
# Original Comment: hum pakistani kuyan nhi jeet paty kia hmra bhi khab pura hoga kabi
# Predicted Sentiment: negative
#
# Original Comment: i have seen face of david miller
# Predicted Sentiment: positive
#
# Original Comment: my team lndia win thanks allah bless all team players
# Predicted Sentiment: positive
#
# Original Comment: congratulations guys keep rocking proud moment jai hind
# Predicted Sentiment: positive
#
# Original Comment: virat kohli fan like
# Predicted Sentiment: positive
#
# Original Comment: thnks sir
# Predicted Sentiment: positive
#
# Original Comment: congratulations blue armylove
# Predicted Sentiment: positive
#
# Original Comment: we all indians felt saneway one nation one emotioncongratulations to all indians
# Predicted Sentiment: positive
#
# Original Comment: weii done india miss you king
# Predicted Sentiment: negative
#
# Original Comment: match winning catch
# Predicted Sentiment: positive
#
# Original Comment: jaha matter bade hote h vaha king khade hote h virat kohli
# Predicted Sentiment: negative
#
# Original Comment: ro super hit man sharma
# Predicted Sentiment: positive
#
# Original Comment: kon kon dhoni ka fan hai
# Predicted Sentiment: positive
#
# Original Comment: sa ke liye bhi bura lag rhi h yar
# Predicted Sentiment: negative
#
# Original Comment: kapil paji wala catch liya surya ne
# Predicted Sentiment: negative
#
# Original Comment: kon kon virat kohli ka fan hai the king ka
# Predicted Sentiment: positive
#
# Original Comment: kon kon virat kohli ka fan he
# Predicted Sentiment: positive
#
# Original Comment: axar ko over deker dil tut gaya par alhamdulillah surya ka catch aur fir hum champions
# Predicted Sentiment: positive
#
# Original Comment: aaj video rukna nhi chahiye sir
# Predicted Sentiment: negative
#
# Original Comment: respect botton bumraah
# Predicted Sentiment: positive
#
# Original Comment: one day world cup dono khelenge
# Predicted Sentiment: positive
#
# Original Comment: thank you very much for giving us all cricket informationand i am seeing tears in you eyes while speakingchak de india fuck de pakistan thank you sirlove youvirat kholi retirement
# Predicted Sentiment: positive
#
# Original Comment: india can do anything
# Predicted Sentiment: positive
#
# Original Comment: surya kumar yadav ka catch game changing catch tha and axar patel ka over ke bad to har tay lag raha tha
# Predicted Sentiment: negative
#
# Original Comment: we wonmera bhai hak se
# Predicted Sentiment: negative
#
# Original Comment: virat jesa player phir ni milly gasoch lena
# Predicted Sentiment: negative
#
# Original Comment: jai bharat love you all my real hero
# Predicted Sentiment: positive
#
# Original Comment: jay hind jay bharata
# Predicted Sentiment: negative
#
# Original Comment: one video of sa
# Predicted Sentiment: positive
#
# Original Comment: log bol chapri bol rhe the pandya ko chapri bna dya south africa dont feel so alone pandya kuch paane k liye kuch khona padta h but very sad for kohli retirement
# Predicted Sentiment: negative
#
# Original Comment: dil se salam india ko
# Predicted Sentiment: positive
#
# Original Comment: i waiting you video
# Predicted Sentiment: positive
#
# Original Comment: is mai koi shak nai k players ki koshishion hor fans ki dhuaon k badly champion ban gai congratulations fans
# Predicted Sentiment: negative
#
# Original Comment: india is the world champion i am indian so i am proud
# Predicted Sentiment: positive
#
# Original Comment: kaun kaun chahta he ki iss jeet ke sath ek movie ho jaae rohit sir ki under captaincy me
# Predicted Sentiment: positive
#
# Original Comment: thank you modi ji acha hua ap match dekhne nai gaye
# Predicted Sentiment: positive
#
# Original Comment: jjko
# Predicted Sentiment: positive
#
# Original Comment: catch of the match
# Predicted Sentiment: positive
#
# Original Comment: from kabul to kandahar we will celebrate our brother victory long live afghanistan india
# Predicted Sentiment: positive
#
# Original Comment: kon kon harana chahata thabolo
# Predicted Sentiment: positive
#
# Original Comment: good game indian team from pakistan
# Predicted Sentiment: positive
#
# Original Comment: hardik pandya remember the name
# Predicted Sentiment: positive
#
# Original Comment: hardik pandya chpri hardik pandya legend player from now
# Predicted Sentiment: positive
#
# Original Comment: sky catch waw waw
# Predicted Sentiment: positive
#
# Original Comment: kon kon virat kohli ke liye dukhi hai
# Predicted Sentiment: negative
#
# Original Comment: like who want to see hardik as next captain
# Predicted Sentiment: positive
#
# Original Comment: sach mein sir humara sabhi duaon ka kamaal hai aur humara squad members ka skill aur team ka environment ka kamaal hai all of us will remember this night finally we did it congratulations
# Predicted Sentiment: positive
#
# Original Comment: congratulations my dear team india
# Predicted Sentiment: positive
#
# Original Comment: arre bhi tum b sabke sath chapri bol rehe the ipl k timekya doglapansabhi player indian e hay support everyone every situation
# Predicted Sentiment: positive
#
# Original Comment: king kohli retirement i cant believe
# Predicted Sentiment: negative
#
# Original Comment: virat aaj dravid ki tarah deewar ki tarah khada tha maja aa gaya surya is another champion
# Predicted Sentiment: positive
#
# Original Comment: thank you for every moment
# Predicted Sentiment: positive
#
# Original Comment: kaun kaun roya tha match k badd nepal se pls assemble here love from nepal
# Predicted Sentiment: positive
#
# Original Comment: congratulations dil jeet lia hindustan nedil se afghanistan
# Predicted Sentiment: positive
#
# Original Comment: india jeet ke bhi haar gyi south africa haar ke bhi jeet gyi trophy se kuch nhi hota real winner is south africa
# Predicted Sentiment: positive
#
# Original Comment: finally sir ro ko complete your dream take over world cup trophy he is deawired
# Predicted Sentiment: positive
#
# Original Comment: many congratulations to team india for the victory
# Predicted Sentiment: positive
#
# Original Comment: when hundred million people want puri kaynat koshish krti hai
# Predicted Sentiment: positive
#
# Original Comment: bhai me sabko dekhke ro raha tha aapne phir ruladiya
# Predicted Sentiment: negative
#
# Original Comment: bjp hari or india vijayavani
# Predicted Sentiment: positive
#
# Original Comment: sase rook gai thi fir bhi india jita
# Predicted Sentiment: positive
#
# Original Comment: hardik ke bareme bolo bhi
# Predicted Sentiment: negative
#
# Original Comment: still enxity
# Predicted Sentiment: negative
#
# Original Comment: rohit sharma se bada captain nahi hai koi mumbai waalo kuch seekho jay shah se
# Predicted Sentiment: negative
#
# Original Comment: king pressure pressure pressure idont like i avoid but pressure likes me i cant avoid
# Predicted Sentiment: negative
#
# Original Comment: kon kon roya
# Predicted Sentiment: positive
#
# Original Comment: hardik bhai op
# Predicted Sentiment: negative
#
# Original Comment: aaj ka emotion kabhi nahi bhulunga
# Predicted Sentiment: negative
#
# Original Comment: mai tho bht ro rha tha i love india
# Predicted Sentiment: positive
#
# Original Comment: mumbai indian management dekh liya na captain rohit sharma ko champion bante you people are responsible for draw line between rohit and hardikshame on you mumbai indian management
# Predicted Sentiment: negative
#
# Original Comment: arshadeep also did the miracle he matches with bumrah in this match
# Predicted Sentiment: positive
#
# Original Comment: bhagwan meri baat suna h
# Predicted Sentiment: positive
#
# Original Comment: surya peak the trophy not catch
# Predicted Sentiment: negative
#
# Original Comment: hanji sir lekin ye sir khushi ke aansu hai
# Predicted Sentiment: negative
#
# Original Comment: only hitman
# Predicted Sentiment: negative
#
# Original Comment: surya ke catch ne match india ki jholi me dal diya
# Predicted Sentiment: positive
#
# Original Comment: love ro hit super hit sharma
# Predicted Sentiment: positive
#
# Original Comment: legend captain aaj sare jakham bhar gaye
# Predicted Sentiment: positive
#
# Original Comment: king kholi our hero
# Predicted Sentiment: positive
#
# Original Comment: hardik ko itna blame kiya ipl main aaj usne sabith kardeya woh har nhi mantehar ke jeet ne waloin ko bazigar kehte hain
# Predicted Sentiment: negative
#
# Original Comment: surya kumar yadav and hardik redeemed themselves reclaimed their lost glory
# Predicted Sentiment: positive
#
# Original Comment: axar ko over dena bhut hi galat decision tha pandya ko dena chahiye tha toh itna run nhi jata but anyway we won the match
# Predicted Sentiment: negative
#
# Original Comment: haan sir kya feelings
# Predicted Sentiment: positive
#
# Original Comment: thank you virat bhaiya and rohit bhaiya for giving us happy and joyful night
# Predicted Sentiment: positive
#
# Original Comment: rohit ne kaha tha semi final jitt ne ke baad ki virat marega bacha khe rakha hai finals ke liya aur achh dikha diya virat ne jab jarurat hoti hai tab king kuch bhi kar sakta hai
# Predicted Sentiment: negative
#
# Original Comment: best of luck congratulations love from indian king kohli run machine jaysa koi nahi
# Predicted Sentiment: positive
#
# Original Comment: hardik ne jo wicket lee aur ye banda jo video bna rha hai ye match k bad sab pta hota hai ajeeb chutiya pa hai
# Predicted Sentiment: negative
#
# Original Comment: good bum bum bro
# Predicted Sentiment: positive
#
# Original Comment: rohit sharma rahul gandhi
# Predicted Sentiment: positive
#
# Original Comment: bharat win
# Predicted Sentiment: positive
#
# Original Comment: virat king kholi ka retirement
# Predicted Sentiment: positive
#
# Original Comment: klasen wicket most important wicket hardik pandya today india win only hardik pandya congratulations india team
# Predicted Sentiment: positive
#
# Original Comment: men in blue shani maharaj ka saal karm ke devta ne fir se samjha diya kikarm karo fal pao
# Predicted Sentiment: negative
#
# Original Comment: bumrahhardiksurya
# Predicted Sentiment: positive
#
# Original Comment: it has now proved that richard kattlebrough pm modi and bhabhiji are not panauti
# Predicted Sentiment: positive
#
# Original Comment: thx god
# Predicted Sentiment: positive
#
# Original Comment: emotion for the reason
# Predicted Sentiment: positive
#
# Original Comment: hardik you are beauty
# Predicted Sentiment: positive
#
# Original Comment: rohit ka big fan awanish yadav bihar
# Predicted Sentiment: positive
#
# Original Comment: koun koun virat ka fan hai from deep heart
# Predicted Sentiment: positive
#
# Original Comment: king kohli very very love you
# Predicted Sentiment: positive
#
# Original Comment: main rohit sharma ka sabse bada fan i love u rohit sharma i love u rohit sharma aapki jo feeling thi jo humne aaj dekhi hai iske liye koi shabd nahin hai so well played
# Predicted Sentiment: positive
#
# Original Comment: team india waale like kare
# Predicted Sentiment: positive
#
# Original Comment: mai to bahut dua ki bhai
# Predicted Sentiment: positive
#
# Original Comment: kohli fan like here
# Predicted Sentiment: positive
#
# Original Comment: virat kohli king ne match jitaya
# Predicted Sentiment: positive
#
# Original Comment: salute sir
# Predicted Sentiment: positive
#
# Original Comment: surya bhai ne catch nhi trophy pakda tha
# Predicted Sentiment: positive
#
# Original Comment: virat kohli chris gayle king kholi
# Predicted Sentiment: positive
#
# Original Comment: just waiting for your video sach mai prayers kam kar geyi or players bhi to day we all can sleep in peace
# Predicted Sentiment: positive
#
# Original Comment: surya ne catch nhi match pkda liya tha
# Predicted Sentiment: positive
#
# Original Comment: mein bahut roya yaar for rohit
# Predicted Sentiment: positive
#
# Original Comment: bohut roya yar aj jeete rahi mere shero
# Predicted Sentiment: positive
#
# Original Comment: jai hind vande matram
# Predicted Sentiment: negative
#
# Original Comment: kohli ki slow pari aakhirkar kaam aaa hi gaya
# Predicted Sentiment: negative
#
# Original Comment: surya bhai ne dil kidni fefda sab jit liya
# Predicted Sentiment: negative
#
# Original Comment: the legend the king king kohli has taken retirement respect to king
# Predicted Sentiment: positive
#
# Original Comment: big stage biggest war high pressure team on backfoot this stage belongs to king kohli
# Predicted Sentiment: negative
#
# Original Comment: virat boom sky tibiya da putt arshdeep bapu kungfuall came togetherbilkul pakistan ki tarah choke karwa diya
# Predicted Sentiment: negative
#
# Original Comment: under pressure very good catch by sky
# Predicted Sentiment: positive
#
# Original Comment: gala sukh chuka tha sase tham gaithi fir ekbar akhon se ansu to nikal nahin rahe the lekin dil se aansu a rahe the
# Predicted Sentiment: negative
#
# Original Comment: so happy
# Predicted Sentiment: positive
#
# Original Comment: dil kush kar diya sury kumar yadav
# Predicted Sentiment: negative
#
# Original Comment: hardik pandiya out to klassen surya kumar yadav catch miller six this is turning point
# Predicted Sentiment: positive
#
# Original Comment: maine to virat kohli ka fan hun love king
# Predicted Sentiment: positive
#
# Original Comment: bumhara as bowler nehi india ka ahsas bangayaworlds best economical bowler
# Predicted Sentiment: positive
#
# Original Comment: congratulations team india from nepal
# Predicted Sentiment: positive
#
# Original Comment: catch nahi trophy pakdi surya ne
# Predicted Sentiment: positive
#
# Original Comment: jai hind ma tujhe salam
# Predicted Sentiment: positive
#
# Original Comment: hardik pandya ne klassen ka wicket liya match ka turning point tha
# Predicted Sentiment: positive
#
# Original Comment: mera to ajj memory h
# Predicted Sentiment: positive
#
# Original Comment: do sabd rinku sing kelie bhi kahie sir rinku sing ne ipl finale kedin kaha tha dekhna isbar world cup hamhi uthaenge unhone bhalehi ekbhi match na khela ho par unka kathan sach huaa
# Predicted Sentiment: negative
#
# Original Comment: and definitely suray ka catch lifetime yaad rhega joginder ki ball pe vo misbah ka catchdhoni ka six and this catch
# Predicted Sentiment: positive
#
# Original Comment: wow team india welldone
# Predicted Sentiment: positive
#
# Original Comment: respect for hardik pandya h klaasen wicket for turning match turning point
# Predicted Sentiment: positive
#
# Original Comment: always support to india
# Predicted Sentiment: positive
#
# Original Comment: suriya kumar bumrah like button
# Predicted Sentiment: positive
#
# Original Comment: kon kon virat ke fan hai
# Predicted Sentiment: positive
#
# Original Comment: congratulation neighbour love from nepal
# Predicted Sentiment: positive
#
# Original Comment: moment jb hum match me aaye when hardik taken henrich classen wicket koun koun sahmat hai like
# Predicted Sentiment: positive
#
# Original Comment: hum jit gaya sir
# Predicted Sentiment: positive
#
# Original Comment: wah kya acting karta he
# Predicted Sentiment: negative
#
# Original Comment: i love rohit and our team
# Predicted Sentiment: positive
#
# Original Comment: credit goes to our bowlers specially bumraah hardik and paji
# Predicted Sentiment: positive
#
# Original Comment: sir aaj aapne real anchoring ki hai
# Predicted Sentiment: positive
#
# Original Comment: hardik pandiya best tumne to sab kuchh badal diya
# Predicted Sentiment: positive
#
# Original Comment: u r ryt sirhar bhagawan almighty ko bulaya h hum sab aur unki dua h sare indians ka hope aur ashirbad se ye sab ho paya
# Predicted Sentiment: positive
#
# Original Comment: sahi mein kya match thawe really deserve this icc wc trophy lv u all guys u r really champ
# Predicted Sentiment: positive
#
# Original Comment: jo khushi apki ankho me dikh rhi hai aaj bahi khushi mere or desh ke logo ki ankho me bhi dikh rhi hai congratulations india
# Predicted Sentiment: positive
#
# Original Comment: bhai sahb ka gla bhar aaya
# Predicted Sentiment: positive
#
# Original Comment: bhai mubarak ho aaj india ne jalwa jalal kar diya
# Predicted Sentiment: negative
#
# Original Comment: rohit sharma is the best
# Predicted Sentiment: positive
#
# Original Comment: hardik fans club
# Predicted Sentiment: positive
#
# Original Comment: virat ko aj itna acha khela koun koun virat ka fan hai
# Predicted Sentiment: positive
#
# Original Comment: gret captan rohit shram and all team india hindustan jindabad
# Predicted Sentiment: positive
#
# Original Comment: sach m main match nhi dekh paya total math m prayer main baith gaya tha bhagwan jitado mera prarthana bhagwan ne sun liye
# Predicted Sentiment: positive
#
# Original Comment: catch nhi wo match tha
# Predicted Sentiment: positive
#
# Original Comment: india win nice video
# Predicted Sentiment: positive
#
# Original Comment: jadeja ko b dilwado ritarment
# Predicted Sentiment: negative
#
# Original Comment: king kohli retired
# Predicted Sentiment: negative
#
# Original Comment: rohit or virat ko itna kyu famous kar rahe ho
# Predicted Sentiment: positive
#
# Original Comment: ye last match thajishme humne virat or rohit ko ek sath khelte dekha
# Predicted Sentiment: negative
#
# Original Comment: bahut rouya m
# Predicted Sentiment: negative
#
# Original Comment: history bumrah ko yaad rakhengi humesha
# Predicted Sentiment: negative
#
# Original Comment: ab bolo dubey ji ke liye ab aap sharam karo dubey ne paari sambhal diya
# Predicted Sentiment: negative
#
# Original Comment: hamni vi habai dekha match bat rohit is best jasprit bumra asrdip and hardik and catha of mach surya kumar best in folders done od job and wine game
# Predicted Sentiment: positive
#
# Original Comment: real hero kon raha is match ka jasprit bhumraha suryakumar yadav hardik pandya who
# Predicted Sentiment: positive
#
# Original Comment: proud of rohit sir
# Predicted Sentiment: positive
#
# Original Comment: to day i am
# Predicted Sentiment: positive
#
# Original Comment: my always favourite rohit sharma
# Predicted Sentiment: positive
#
# Original Comment: sky ne catch nhi usne world cup ki trophy pakdi thi bhaii kon agree karte ho
# Predicted Sentiment: positive
#
# Original Comment: sky catch is turning point
# Predicted Sentiment: positive
#
# Original Comment: chamatkar type ko jita hai bhai india
# Predicted Sentiment: positive
#
# Original Comment: surya bhau ne apne career ka best catch nhi balki india ne liye trophy pakdi thi
# Predicted Sentiment: positive
#
# Original Comment: congratulations to all lions
# Predicted Sentiment: positive
#
# Original Comment: ab bole koi virat k bare m jab sab fail tab virat bhai ne kar dikhayamuh band ho gaya ab
# Predicted Sentiment: negative
#
# Original Comment: mai to rone lga tha bhai khushi se
# Predicted Sentiment: negative
#
# Original Comment: video save in gallary ye video aane vaalai generation dekhe gi
# Predicted Sentiment: positive
#
# Original Comment: rahul dravid bildan coach
# Predicted Sentiment: positive
#
# Original Comment: we are a champions
# Predicted Sentiment: positive
#
# Original Comment: east aur west india is best
# Predicted Sentiment: positive
#
# Original Comment: mekeup kam kiya kar we are champion you are content creator
# Predicted Sentiment: positive
#
# Original Comment: virat bumrah hardik rohit sharma
# Predicted Sentiment: positive
#
# Original Comment: virat kohli last word cup so sed
# Predicted Sentiment: negative
#
# Original Comment: virat kohli miss you bhai
# Predicted Sentiment: negative
#
# Original Comment: we have balanced batting and bowling players it was a great team effort proud of our team congratulations guys you all deserve this trophy
# Predicted Sentiment: positive
#
# Original Comment: me is raat ko nahi bhulunga
# Predicted Sentiment: positive
#
# Original Comment: bomrah deserve arjun award
# Predicted Sentiment: positive
#
# Original Comment: virat is king and king is always king
# Predicted Sentiment: positive
#
# Original Comment: l love you indai
# Predicted Sentiment: positive
#
# Original Comment: kohli is star sir ji dont miss kohli
# Predicted Sentiment: positive
#
# Original Comment: kis kis ke asu aygye
# Predicted Sentiment: negative
#
# Original Comment: hardik what a comeback brother i big hug for you
# Predicted Sentiment: positive
#
# Original Comment: bapu ka badla liya train se nikalne ka final se nikal kar bhai
# Predicted Sentiment: negative
#
# Original Comment: mai bhi
# Predicted Sentiment: positive
#
# Original Comment: as a indian south africa world cup jeetna deserve karta tha very sad for south africa
# Predicted Sentiment: negative
#
# Original Comment: f man kya catch the
# Predicted Sentiment: positive
#
# Original Comment: congratulations time india congratulations hitman
# Predicted Sentiment: positive
#
# Original Comment: aaj mera janmadin hai but no one wish me
# Predicted Sentiment: negative
#
# Original Comment: aj inda ne pure afghanistan walo ka badla be le liya or world cup be jeet liya congrats afghantan bhaiyao or inda walo congrats
# Predicted Sentiment: positive
#
# Original Comment: i am also sir congratulations rahit sir and all team india
# Predicted Sentiment: positive
#
# Original Comment: ye jeet isreal ke naam
# Predicted Sentiment: positive
#
# Original Comment: thank you king kohli for all the things
# Predicted Sentiment: positive
#
# Original Comment: dubey ko troll kr rha tha kya be
# Predicted Sentiment: negative
#
# Original Comment: duvao ka hi phal tnx god
# Predicted Sentiment: positive
#
# Original Comment: mba chaye wala panoti
# Predicted Sentiment: positive
#
# Original Comment: what an effort proud to be fan of this teamwe are champion
# Predicted Sentiment: positive
#
# Original Comment: koi shand nbhai mere pass
# Predicted Sentiment: positive
#
# Original Comment: king amp hardik no replacement
# Predicted Sentiment: negative
#
# Original Comment: surya bhai salam h aapko love you blue army
# Predicted Sentiment: positive
#
# Original Comment: congratulations alll of you
# Predicted Sentiment: positive
#
# Original Comment: gajab bhai
# Predicted Sentiment: positive
#
# Original Comment: thanks for sky catch
# Predicted Sentiment: positive
#
# Original Comment: congratulations all indian cricket team i proud to be indian
# Predicted Sentiment: positive
#
# Original Comment: sirf dua ka asar hai bhai hamne dua ki thi jab bhumra ne wicket liya tha jansen ka tab allah pak aaj india ko jita de world cup dua qubool huyi jai hind
# Predicted Sentiment: negative
#
# Original Comment: catch nahi world cup ko pakada hai salute for india
# Predicted Sentiment: positive
#
# Original Comment: my febret hiro hardik panday
# Predicted Sentiment: positive
#
# Original Comment: har ke jitne wale ko kahta hai india
# Predicted Sentiment: negative
#
# Original Comment: suriya kumar ka catch keli he ek like toh banta hai
# Predicted Sentiment: positive
#
# Original Comment: heartful respect button fr whole indian team efforts all players give their bestmy tears r not stoping
# Predicted Sentiment: positive
#
# Original Comment: sach me aansu aa gaya
# Predicted Sentiment: positive
#
# Original Comment: aaj mai tumko gali nahi de raha hu lekin tumne hardik ko barbaad karne ki puri kosis kari pure ipl me kah rahe the hardik se behtar dube hai sharm aani vhahiye tumhe
# Predicted Sentiment: negative
#
# Original Comment: sir mai booht bhawook is time
# Predicted Sentiment: positive
#
# Original Comment: aaj first time halat kharab ho gayi thi bohat wadiya indian team love you all
# Predicted Sentiment: positive
#
# Original Comment: virat snail pace inns nearly sunk india in this final but qudos to hardik klaseen wicket then suryas catch nailed the wc for india arshadeep was also fabolous
# Predicted Sentiment: positive
#
# Original Comment: kahan gye virat aur hardik ko troll krne wale chhapri aur chokli kahne wale
# Predicted Sentiment: negative
#
# Original Comment: ye dono loag sanyas na le
# Predicted Sentiment: negative
#
# Original Comment: sapna jese lag raha hai
# Predicted Sentiment: negative
#
# Original Comment: bumrah the greatest white ball bowler
# Predicted Sentiment: positive
#
# Original Comment: words cant describe the joy congratulations team india youve made history this victory is etched in our hearts
# Predicted Sentiment: positive
#
# Original Comment: i love rohit sharma and virat kohli king
# Predicted Sentiment: positive
#
# Original Comment: i india team
# Predicted Sentiment: positive
#
# Original Comment: very well played team india congratulations
# Predicted Sentiment: positive
#
# Original Comment: kash ye like ke button ko unlimited time press karne ka access de de youtube walekasam se itna like karunga mishra jeebus kya hi bole
# Predicted Sentiment: positive
#
# Original Comment: eaisa khushi jisme rona aa raha he eaise khushi ke liye mujhe roj rona manjur he
# Predicted Sentiment: positive
#
# Original Comment: all eyes in tears raw emotion staggering
# Predicted Sentiment: negative
#
# Original Comment: allah wale harane ki ibadat kar rahe their
# Predicted Sentiment: negative
#
# Original Comment: well played team india ab to khushi ke aashu aaye yarrr
# Predicted Sentiment: positive
#
# Original Comment: sir ji catch n vo hmari jaan hai
# Predicted Sentiment: negative
#
# Original Comment: har kar jitne bale team ko india kahte hai i love india
# Predicted Sentiment: positive
#
# Original Comment: congratulations to whole india khushi ke aasu aa gye bhai
# Predicted Sentiment: positive
#
# Original Comment: bhenchooooood jeeet gayyye let the tears come out cause we deserve this tears of happiness
# Predicted Sentiment: positive
#
# Original Comment: rohit sahab aur kohli sahab hmesha khelte rhe
# Predicted Sentiment: positive
#
# Original Comment: history has been created by the the legend quotrohit sharmaquot
# Predicted Sentiment: positive
#
# Original Comment: aj india wale mucher ne mach jeeta diya congrats
# Predicted Sentiment: positive
#
# Original Comment: respect our bowler
# Predicted Sentiment: positive
#
# Original Comment: boom boom bumrah and hardik pandya
# Predicted Sentiment: positive
#
# Original Comment: only king kohli i love virat kohli
# Predicted Sentiment: positive
#
# ...
# Predicted Sentiment: positive
#
# Original Comment: hardik and bumrah in real hero
# Predicted Sentiment: positive
#
# Original Comment: respect button for hardik pandya
# Predicted Sentiment: positive
#
# Original Comment: hardik pandya salute
# Predicted Sentiment: positive
#
# Original Comment: india team mein cricket jitne mein sabse badi bhumika kiski rahi
# Predicted Sentiment: negative
#
# Original Comment: virat kohli and rohit sharma love you
# Predicted Sentiment: positive
#
# Original Comment: love u hardik pandya
# Predicted Sentiment: positive
#
# Original Comment: tm apne channel bnd kr doq ki tm bhot paltibaaz aadmiho
# Predicted Sentiment: negative
#
# Original Comment: happy for team india win but sad for king retirement
# Predicted Sentiment: neutral
#
# Original Comment: aaj ke match ka hero bumrah arshdeep singh hardik pandya and virat kohli
# Predicted Sentiment: positive
#
# Original Comment: such me aaise hi lag raha tha pure over heart beat dhak dhak ro raha tha
# Predicted Sentiment: positive
#
# Original Comment: congratulation very very good india cricket team best of luck india
# Predicted Sentiment: positive
#
# Original Comment: really brother anshu aagay
# Predicted Sentiment: positive
#
# Original Comment: bhaiya aap ka video dekhane ke liye kab se intjar kar raha tha love you bhaiya ham sab jit gaye
# Predicted Sentiment: positive
#
# Original Comment: injammam aalo kahega match fix tha
# Predicted Sentiment: negative
#
# Original Comment: congratulations india jay shree ram
# Predicted Sentiment: positive
#
# Original Comment: i miss you sir iam santosh jay ho
# Predicted Sentiment: negative
#
# Original Comment: tumari video ki waiting me tha
# Predicted Sentiment: positive
#
# Original Comment: only hardhik
# Predicted Sentiment: negative
#
# Original Comment: love you sir mujhe pta hai aap v hmari trah emotional ho
# Predicted Sentiment: positive
#
# Original Comment: leagend captain rohit sharma
# Predicted Sentiment: positive
#
# Original Comment: im waiting of you sirrrrrrr
# Predicted Sentiment: positive
#
# Original Comment: hardik panday jindabad jindabad jindabad
# Predicted Sentiment: negative
#
# Original Comment: india winner
# Predicted Sentiment: positive
#
# Original Comment: rohit my heart
# Predicted Sentiment: negative
#
# Original Comment: hardik hartich
# Predicted Sentiment: negative
#
# Original Comment: r v b h
# Predicted Sentiment: positive
#
# Original Comment: sky is the limit lesscatch of the tournament
# Predicted Sentiment: negative
#
# Original Comment: sir apse nivedan hai kripya hmse contact kijiye
# Predicted Sentiment: positive
#
# Original Comment: bhoom bhoom bumra
# Predicted Sentiment: positive
#
# Original Comment: abb bolo beta king power asli king virat kohli hai
# Predicted Sentiment: positive
#
# Original Comment: virat kohli ko dil se salute kon kon karta hai like kare
# Predicted Sentiment: positive
#
# Original Comment: we are champion
# Predicted Sentiment: positive
#
# Original Comment: indian fans subscribe kro please
# Predicted Sentiment: positive
#
# Original Comment: congratulations to all of you so much
# Predicted Sentiment: positive
#
# Original Comment: ek samay to bharat har hi jayega
# Predicted Sentiment: positive
#
# Original Comment: sir congratulations
# Predicted Sentiment: positive
#
# Original Comment: sir aaj khusi ki aashu ruk nhi rha hai
# Predicted Sentiment: negative
#
# Original Comment: incredible victory for india
# Predicted Sentiment: positive
#
# Original Comment: sar apko badaho
# Predicted Sentiment: negative
#
# Original Comment: india india champion champion love amp respect from afghanistan
# Predicted Sentiment: positive
#
# Original Comment: congratulations india proud of you
# Predicted Sentiment: positive
#
# Original Comment: never underestimate power of gujju pandya bumrah axar n jaddu
# Predicted Sentiment: positive
#
# Original Comment: hardhik the future captain
# Predicted Sentiment: positive
#
# Original Comment: script is good
# Predicted Sentiment: positive
#
# Original Comment: shubhankar bhai mje hi mje ho gye nice video love u bhai
# Predicted Sentiment: positive
#
# Original Comment: virat is the most reliable player
# Predicted Sentiment: positive
#
# Original Comment: congratulations india after every matchi like to watch your video
# Predicted Sentiment: positive
#
# Original Comment: virat i love you
# Predicted Sentiment: positive
#
# Original Comment: team india you deserve it
# Predicted Sentiment: positive
#
# Original Comment: bol sale dube ke baare me bol re saale
# Predicted Sentiment: negative
#
# Original Comment: mai puri teem ko congretchulation bolunga
# Predicted Sentiment: negative
#
# Original Comment: i love india jai hind
# Predicted Sentiment: positive
#
# Original Comment: virat kohli fan
# Predicted Sentiment: positive
#
# Original Comment: thanks so much india team
# Predicted Sentiment: positive
#
# Original Comment: you india
# Predicted Sentiment: positive
#
# Original Comment: king is alwys king
# Predicted Sentiment: positive
#
# Original Comment: e dh bast rohit sharma
# Predicted Sentiment: positive
#
# Original Comment: maturity is when you realising that sky caught the world cup trophy winning the wc trophy
# Predicted Sentiment: positive
#
# Original Comment: koun koun subhankar ke video ka intajaar kr rha tha
# Predicted Sentiment: positive
#
# Original Comment: love you rohit happy
# Predicted Sentiment: positive
#
# Original Comment: hardik bahut troll kiye the bro
# Predicted Sentiment: negative
#
# Original Comment: victory india
# Predicted Sentiment: positive
#
# Original Comment: wahi pandaya jo ipl me indian fan troll kiye hai wahi ajjj thrif kar rahe hai
# Predicted Sentiment: negative
#
# Original Comment: india jeet gayi
# Predicted Sentiment: positive
#
# Original Comment: viralrohit india i am right comment viral kr do indians
# Predicted Sentiment: positive
#
# Original Comment: why virat kohli why yaar kohli ne sanyas le liya t twenty world cup se
# Predicted Sentiment: negative
#
# Original Comment: ab bolo be shubhakar dube ke bare me
# Predicted Sentiment: negative
#
# Original Comment: what a comeback king kohli
# Predicted Sentiment: positive
#
# Original Comment: i love india and rohit sharma
# Predicted Sentiment: positive
#
# Original Comment: congratulations subhankar mishra brother
# Predicted Sentiment: positive
#
# Original Comment: king retired
# Predicted Sentiment: positive
#
# Original Comment: surya kumar ka catch
# Predicted Sentiment: positive
#
# Original Comment: virat kohli and rohit sharma
# Predicted Sentiment: positive
#
# Original Comment: virat retire bhai
# Predicted Sentiment: negative
#
# Original Comment: rohit sharma the best captain
# Predicted Sentiment: positive
#
# Original Comment: hiridik ne match jita diya
# Predicted Sentiment: positive
#
# Original Comment: virat rohit axar
# Predicted Sentiment: negative
#
# Original Comment: thanks for reporting thanks for indian teams final kab hua vah bahut bahut mubarak jay hind jay sanvidhan
# Predicted Sentiment: positive
#
# Original Comment: world se to khusi mili but ek dukh bhi deke gaya virat kohli ne
# Predicted Sentiment: negative
#
# Original Comment: like this comment for india team
# Predicted Sentiment: positive
#
# Original Comment: shree radhe kishna
# Predicted Sentiment: positive
#
# Original Comment: rohit sir love you
# Predicted Sentiment: positive
#
# Original Comment: virat sir jaisa abhi current koi nhi hai thanks king kohli
# Predicted Sentiment: positive
#
# Original Comment: best feeling this time
# Predicted Sentiment: positive
#
# Original Comment: aap ko video ka intezar kar rahe the
# Predicted Sentiment: positive
#
# Original Comment: true
# Predicted Sentiment: positive
#
# Original Comment: respect button for team india
# Predicted Sentiment: positive
#
# Original Comment: sir mai apka hi video ka wait kr raha tha besabri se
# Predicted Sentiment: positive
#
# Original Comment: islam haar gya mubarak ho
# Predicted Sentiment: positive
#
# Original Comment: hardik op
# Predicted Sentiment: negative
#
# Original Comment: love for indian team
# Predicted Sentiment: positive
#
# Original Comment: itni khushi etna sukoon jidagi main pehli baar mila hai
# Predicted Sentiment: negative
#
# Original Comment: maza aagya kasam se dil mai bahut dard ho raha tha
# Predicted Sentiment: negative
#
# Original Comment: aaj chhapri ne to kamal kar diya bhi
# Predicted Sentiment: negative
#
# Original Comment: khash hardik one day me bhi hota
# Predicted Sentiment: negative
#
# Original Comment: bahut bahut badhaai ho aap sab ko
# Predicted Sentiment: negative
#
# Original Comment: finnally world cup win indian
# Predicted Sentiment: positive
#
# Original Comment: congratulations mai india love you india
# Predicted Sentiment: positive
#
# Original Comment: i love india time
# Predicted Sentiment: positive
#
# Original Comment: mi hardij thim india hardik
# Predicted Sentiment: positive
#
# Original Comment: cricket ka sabse most moment kaun sa raha
# Predicted Sentiment: positive
#
# Original Comment: virat kohli fans like
# Predicted Sentiment: positive
#
# Original Comment: love you rohit sir congratulations
# Predicted Sentiment: positive
#
# Original Comment: ek like
# Predicted Sentiment: positive
#
# Original Comment: tq team india
# Predicted Sentiment: positive
#
# Original Comment: rohit sharma the legend
# Predicted Sentiment: positive
#
# Original Comment: ke se pehle mujhe aa gya tha sir me
# Predicted Sentiment: negative
#
# Original Comment: love v rohit and virat bhai
# Predicted Sentiment: positive
#
# Original Comment: kingfu pandya
# Predicted Sentiment: positive
#
# Original Comment: rohit sharma legend
# Predicted Sentiment: positive
#
# Original Comment: saare jahan se achha hindustan hamara
# Predicted Sentiment: negative
#
# Original Comment: rosuper hitman
# Predicted Sentiment: positive
#
# Original Comment: kb se wait kr rhe the sir aappka video
# Predicted Sentiment: positive
#
# Original Comment: congratulations bhiya aapko bhi
# Predicted Sentiment: positive
#
# Original Comment: literally i am waiting for your video
# Predicted Sentiment: positive
#
# Original Comment: ind won
# Predicted Sentiment: positive
#
# Original Comment: love from nepal always support indian team after nepal
# Predicted Sentiment: positive
#
# Original Comment: finally we won congratulations india
# Predicted Sentiment: positive
#
# Original Comment: love you pandaya
# Predicted Sentiment: positive
#
# Original Comment: virat take retired
# Predicted Sentiment: negative
#
# Original Comment: catch ne match jeeta diya
# Predicted Sentiment: positive
#
# Original Comment: sir we are champions
# Predicted Sentiment: positive
#
# Original Comment: aap hi k wet kar raha tha aapko sun kar light off krunga
# Predicted Sentiment: negative
#
# Original Comment: sir g kab se wait krre the
# Predicted Sentiment: negative
#
# Original Comment: we finally won love you virat and hitman
# Predicted Sentiment: positive
#
# Original Comment: team india played very well
# Predicted Sentiment: positive
#
# Original Comment: support him
# Predicted Sentiment: positive
#
# Original Comment: tabhi se wait kiy aapke video ka
# Predicted Sentiment: positive
#
# Original Comment: kaun kaun roya tha match ke baad
# Predicted Sentiment: positive
#
# Original Comment: bumrah bhai thank u tu nhi hota to aaj trophy bhi nhi hota
# Predicted Sentiment: positive
#
# Original Comment: kungfu pandya
# Predicted Sentiment: positive
#
# Original Comment: king king inning
# Predicted Sentiment: positive
#
# Original Comment: universe
# Predicted Sentiment: positive
#
# Original Comment: i love ind
# Predicted Sentiment: positive
#
# Original Comment: jay hind rohit sharma
# Predicted Sentiment: positive
#
# Original Comment: respect button for indian team
# Predicted Sentiment: positive
#
# Original Comment: kis kis video ka intezar tha
# Predicted Sentiment: positive
#
# Original Comment: india world cup win button
# Predicted Sentiment: positive
#
# Original Comment: east or west our india is best
# Predicted Sentiment: positive
#
# Original Comment: congratulations all ind
# Predicted Sentiment: positive
#
# Original Comment: world championshipindia
# Predicted Sentiment: positive
#
# Original Comment: respect button of hitman sharma
# Predicted Sentiment: positive
#
# Original Comment: fast coment
# Predicted Sentiment: positive
#
# Original Comment: legend virat kohli
# Predicted Sentiment: positive
#
# Original Comment: surya and hardik ka last kamal
# Predicted Sentiment: positive
#
# Original Comment: thank you rohit sharma congratulations
# Predicted Sentiment: positive
#
# Original Comment: rohit ke fan channel ko subscribe kre
# Predicted Sentiment: positive
#
# Original Comment: bhai hm jit to gye but virat sir ne retire le liya
# Predicted Sentiment: negative
#
# Original Comment: me apka vedio dekhne ka intejar ke rha tha
# Predicted Sentiment: negative
#
# Original Comment: viral kohli respect button
# Predicted Sentiment: positive
#
# Original Comment: i my indea
# Predicted Sentiment: positive
#
# Original Comment: india deserves this rohit and virat deserves this trophy
# Predicted Sentiment: positive
#
# Original Comment: wow bhai shina tan hogaya
# Predicted Sentiment: positive
#
# Original Comment: king kohli ka strong comeback in final match
# Predicted Sentiment: positive
#
# Original Comment: bolane aaya tha india world cup jeet ki
# Predicted Sentiment: positive
#
# Original Comment: first comment like karo team india ke liye
# Predicted Sentiment: positive
#
# Original Comment: sar sawth afrika kha jita hai
# Predicted Sentiment: positive
#
# Original Comment: respect button teamindia and rohit sharma like ka button tod dalo
# Predicted Sentiment: positive
#
# Original Comment: jay hind team india
# Predicted Sentiment: positive
#
# Original Comment: team india ke liye ek like
# Predicted Sentiment: positive
#
# Original Comment: virat kohli ke liye like krdo
# Predicted Sentiment: negative
#
# Original Comment: one like for team india
# Predicted Sentiment: positive
#
# Original Comment: my fist comments
# Predicted Sentiment: negative
#
# Original Comment: kahate hain humko india wale
# Predicted Sentiment: positive
#
# Original Comment: ham jit gai
# Predicted Sentiment: positive
#
# Original Comment: india respects the baton
# Predicted Sentiment: positive
#
# Original Comment: sir main aapka video ka wait kar raha tha
# Predicted Sentiment: positive
#
# Original Comment: yes we are champion
# Predicted Sentiment: positive
#
# Original Comment: rohit virat fan like button
# Predicted Sentiment: positive
#
# Original Comment: joy hind
# Predicted Sentiment: positive
#
# Original Comment: mishra ji delay kr diya
# Predicted Sentiment: negative
#
# Original Comment: ram ram bhai congratulations to all
# Predicted Sentiment: positive
#
# Original Comment: fast like
# Predicted Sentiment: positive
#
# Original Comment: congratulations team india and supporters
# Predicted Sentiment: positive
#
# Original Comment: nepal frist comment dekhte he kitna like milta hai
# Predicted Sentiment: negative
#
# Original Comment: frist like comment
# Predicted Sentiment: negative
#
# Original Comment: congratulation team india well done
# Predicted Sentiment: positive
#
# Original Comment: ji sir
# Predicted Sentiment: positive
#
# Original Comment: cack de india
# Predicted Sentiment: negative
#
# Original Comment: love you sarr
# Predicted Sentiment: positive
#
# Original Comment: virat is best
# Predicted Sentiment: positive
#
# Original Comment: virat retire
# Predicted Sentiment: negative
#
# Original Comment: my first views
# Predicted Sentiment: positive
#
# Overall Sentiment of Comments:
# Positive: 68.74%
# Negative: 30.57%
# Neutral: 0.69%
# No ground truth labels found for accuracy calculation.
#                                          Cleaned_Comment Predicted_Sentiment
# 0                                         watching today            positive
# 1      sa donated the cup to india these sa players c...            negative
# 2                                            i am crying            negative
# 3                      uff the commentary is at its best            positive
# 4                                          forever india            positive
# ...                                                  ...                 ...
# 14095                                      cack de india            negative
# 14096                                      love you sarr            positive
# 14097                                      virat is best            positive
# 14098                                       virat retire            negative
# 14099                                     my first views            positive
#
# [14100 rows x 2 columns]
