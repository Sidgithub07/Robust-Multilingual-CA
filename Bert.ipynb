# %%
import re
import pandas as pd
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from sklearn.metrics import accuracy_score
from torch.nn.functional import softmax

# Load the CSV file (assuming the file has a 'label' column with ground truth labels)
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/cleaned_comments_set4.csv')
tot_count = len(df['all_eng'])

# Initialize tokenizer and model for BERT Multilingual Sentiment Analysis
model_name = "nlptown/bert-base-multilingual-uncased-sentiment"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name)

comment_list = []
sentiment_list = []

# Set model to evaluation mode (disable dropout)
model.eval()

# Preprocessing function to clean text
def preprocess_text(text):
    # Remove emojis, punctuation, and special characters (keep commas)
    text = re.sub(r'[^\w\s,]', '', text)

    # Remove brackets and content inside them
    text = re.sub(r'\[.*?\]', '', text)  # Removes square brackets and the content inside them
    text = re.sub(r'\(.*?\)', '', text)  # Removes parentheses and the content inside them

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# Function to classify a comment
def classify_comment(cleaned_text):
    # Tokenize and predict
    inputs = tokenizer(cleaned_text, return_tensors="pt", truncation=True, padding="max_length", max_length=512)
    with torch.no_grad():
        logits = model(**inputs).logits

    # Apply softmax to get probabilities for each class
    probabilities = softmax(logits, dim=1).squeeze().tolist()

    # Get predicted sentiment class (0 to 4) and label
    predicted_class_id = logits.argmax().item()

    # Map the prediction to sentiment labels
    if predicted_class_id <= 1:
        sentiment_label = "NEGATIVE"
    elif predicted_class_id == 2:
        sentiment_label = "NEUTRAL"
    else:
        sentiment_label = "POSITIVE"

    return sentiment_label, probabilities

# Lists to hold predicted labels and true labels
predicted_labels = []
true_labels = df['label'].tolist() if 'label' in df.columns else None  # Ground truth labels, if available

# Sentiment count dictionary to summarize sentiment distribution
sentiment_counts = {'NEGATIVE': 0, 'NEUTRAL': 0, 'POSITIVE': 0}

# Loop through each comment in the DataFrame, preprocess, classify, and gather results
for comment in df['all_eng']:
    # Preprocess the comment
    cleaned_comment = preprocess_text(comment)

    # Classify the preprocessed comment
    predicted_label, probabilities = classify_comment(cleaned_comment)
    predicted_labels.append(predicted_label)

    # Count the sentiment type for summary
    sentiment_counts[predicted_label] += 1

    #for final csv file
    comment_list += [comment]
    sentiment_list += [predicted_label]

    # Optional: Print the original, cleaned comment, and predicted sentiment
    print(f"Original Comment: {comment}")
    print(f"Cleaned Comment: {cleaned_comment}")
    print(f"Predicted Sentiment: {predicted_label}")
    print()

# Calculate sentiment percentages for each category
total_comments = len(df['all_eng'])
percent_negative = (sentiment_counts['NEGATIVE'] / total_comments) * 100
percent_neutral = (sentiment_counts['NEUTRAL'] / total_comments) * 100
percent_positive = (sentiment_counts['POSITIVE'] / total_comments) * 100

# Print the overall sentiment summary
print(f"Overall Sentiment of Comments:")
print(f"Negative: {percent_negative:.2f}%")
print(f"Neutral: {percent_neutral:.2f}%")
print(f"Positive: {percent_positive:.2f}%")

# Calculate accuracy if true labels are provided
if true_labels is not None:
    accuracy = accuracy_score(true_labels, predicted_labels)
    print(f"Accuracy of the model: {accuracy * 100:.2f}%")
else:
    print("No ground truth labels found for accuracy calculation.")

dict = {'Cleaned_Comment': comment_list,
        'Predicted_Sentiment': sentiment_list,

}

df_new = pd.DataFrame(dict)
df_new.to_csv('final_output_bert_set4.csv', index=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/669M [00:00<?, ?B/s]
# Streaming output truncated to the last 5000 lines.
# Cleaned Comment: bapu ka badla liya train se nikalne ka final se nikal kar bhai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: mai bhi
# Cleaned Comment: mai bhi
# Predicted Sentiment: NEGATIVE
#
# Original Comment: as a indian south africa world cup jeetna deserve karta tha very sad for south africa
# Cleaned Comment: as a indian south africa world cup jeetna deserve karta tha very sad for south africa
# Predicted Sentiment: NEGATIVE
#
# Original Comment: f man kya catch the
# Cleaned Comment: f man kya catch the
# Predicted Sentiment: NEGATIVE
#
# Original Comment: congratulations time india congratulations hitman
# Cleaned Comment: congratulations time india congratulations hitman
# Predicted Sentiment: POSITIVE
#
# Original Comment: aaj mera janmadin hai but no one wish me
# Cleaned Comment: aaj mera janmadin hai but no one wish me
# Predicted Sentiment: NEUTRAL
#
# Original Comment: aj inda ne pure afghanistan walo ka badla be le liya or world cup be jeet liya congrats afghantan bhaiyao or inda walo congrats
# Cleaned Comment: aj inda ne pure afghanistan walo ka badla be le liya or world cup be jeet liya congrats afghantan bhaiyao or inda walo congrats
# Predicted Sentiment: NEGATIVE
#
# Original Comment: i am also sir congratulations rahit sir and all team india
# Cleaned Comment: i am also sir congratulations rahit sir and all team india
# Predicted Sentiment: POSITIVE
#
# Original Comment: ye jeet isreal ke naam
# Cleaned Comment: ye jeet isreal ke naam
# Predicted Sentiment: NEGATIVE
#
# Original Comment: thank you king kohli for all the things
# Cleaned Comment: thank you king kohli for all the things
# Predicted Sentiment: POSITIVE
#
# Original Comment: dubey ko troll kr rha tha kya be
# Cleaned Comment: dubey ko troll kr rha tha kya be
# Predicted Sentiment: NEUTRAL
#
# Original Comment: duvao ka hi phal tnx god
# Cleaned Comment: duvao ka hi phal tnx god
# Predicted Sentiment: POSITIVE
#
# Original Comment: mba chaye wala panoti
# Cleaned Comment: mba chaye wala panoti
# Predicted Sentiment: NEGATIVE
#
# Original Comment: what an effort proud to be fan of this teamwe are champion
# Cleaned Comment: what an effort proud to be fan of this teamwe are champion
# Predicted Sentiment: POSITIVE
#
# Original Comment: koi shand nbhai mere pass
# Cleaned Comment: koi shand nbhai mere pass
# Predicted Sentiment: NEUTRAL
#
# Original Comment: king amp hardik no replacement
# Cleaned Comment: king amp hardik no replacement
# Predicted Sentiment: NEGATIVE
#
# Original Comment: surya bhai salam h aapko love you blue army
# Cleaned Comment: surya bhai salam h aapko love you blue army
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulations alll of you
# Cleaned Comment: congratulations alll of you
# Predicted Sentiment: POSITIVE
#
# Original Comment: gajab bhai
# Cleaned Comment: gajab bhai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: thanks for sky catch
# Cleaned Comment: thanks for sky catch
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulations all indian cricket team i proud to be indian
# Cleaned Comment: congratulations all indian cricket team i proud to be indian
# Predicted Sentiment: POSITIVE
#
# Original Comment: sirf dua ka asar hai bhai hamne dua ki thi jab bhumra ne wicket liya tha jansen ka tab allah pak aaj india ko jita de world cup dua qubool huyi jai hind
# Cleaned Comment: sirf dua ka asar hai bhai hamne dua ki thi jab bhumra ne wicket liya tha jansen ka tab allah pak aaj india ko jita de world cup dua qubool huyi jai hind
# Predicted Sentiment: NEGATIVE
#
# Original Comment: catch nahi world cup ko pakada hai salute for india
# Cleaned Comment: catch nahi world cup ko pakada hai salute for india
# Predicted Sentiment: POSITIVE
#
# Original Comment: my febret hiro hardik panday
# Cleaned Comment: my febret hiro hardik panday
# Predicted Sentiment: POSITIVE
#
# Original Comment: har ke jitne wale ko kahta hai india
# Cleaned Comment: har ke jitne wale ko kahta hai india
# Predicted Sentiment: NEGATIVE
#
# Original Comment: suriya kumar ka catch keli he ek like toh banta hai
# Cleaned Comment: suriya kumar ka catch keli he ek like toh banta hai
# Predicted Sentiment: NEUTRAL
#
# Original Comment: heartful respect button fr whole indian team efforts all players give their bestmy tears r not stoping
# Cleaned Comment: heartful respect button fr whole indian team efforts all players give their bestmy tears r not stoping
# Predicted Sentiment: POSITIVE
#
# Original Comment: sach me aansu aa gaya
# Cleaned Comment: sach me aansu aa gaya
# Predicted Sentiment: NEUTRAL
#
# Original Comment: aaj mai tumko gali nahi de raha hu lekin tumne hardik ko barbaad karne ki puri kosis kari pure ipl me kah rahe the hardik se behtar dube hai sharm aani vhahiye tumhe
# Cleaned Comment: aaj mai tumko gali nahi de raha hu lekin tumne hardik ko barbaad karne ki puri kosis kari pure ipl me kah rahe the hardik se behtar dube hai sharm aani vhahiye tumhe
# Predicted Sentiment: NEGATIVE
#
# Original Comment: sir mai booht bhawook is time
# Cleaned Comment: sir mai booht bhawook is time
# Predicted Sentiment: POSITIVE
#
# Original Comment: aaj first time halat kharab ho gayi thi bohat wadiya indian team love you all
# Cleaned Comment: aaj first time halat kharab ho gayi thi bohat wadiya indian team love you all
# Predicted Sentiment: POSITIVE
#
# Original Comment: virat snail pace inns nearly sunk india in this final but qudos to hardik klaseen wicket then suryas catch nailed the wc for india arshadeep was also fabolous
# Cleaned Comment: virat snail pace inns nearly sunk india in this final but qudos to hardik klaseen wicket then suryas catch nailed the wc for india arshadeep was also fabolous
# Predicted Sentiment: NEGATIVE
#
# Original Comment: kahan gye virat aur hardik ko troll krne wale chhapri aur chokli kahne wale
# Cleaned Comment: kahan gye virat aur hardik ko troll krne wale chhapri aur chokli kahne wale
# Predicted Sentiment: NEGATIVE
#
# Original Comment: ye dono loag sanyas na le
# Cleaned Comment: ye dono loag sanyas na le
# Predicted Sentiment: NEUTRAL
#
# Original Comment: sapna jese lag raha hai
# Cleaned Comment: sapna jese lag raha hai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: bumrah the greatest white ball bowler
# Cleaned Comment: bumrah the greatest white ball bowler
# Predicted Sentiment: POSITIVE
#
# Original Comment: words cant describe the joy congratulations team india youve made history this victory is etched in our hearts
# Cleaned Comment: words cant describe the joy congratulations team india youve made history this victory is etched in our hearts
# Predicted Sentiment: POSITIVE
#
# Original Comment: i love rohit sharma and virat kohli king
# Cleaned Comment: i love rohit sharma and virat kohli king
# Predicted Sentiment: POSITIVE
#
# Original Comment: i india team
# Cleaned Comment: i india team
# Predicted Sentiment: POSITIVE
#
# Original Comment: very well played team india congratulations
# Cleaned Comment: very well played team india congratulations
# Predicted Sentiment: POSITIVE
#
# Original Comment: kash ye like ke button ko unlimited time press karne ka access de de youtube walekasam se itna like karunga mishra jeebus kya hi bole
# Cleaned Comment: kash ye like ke button ko unlimited time press karne ka access de de youtube walekasam se itna like karunga mishra jeebus kya hi bole
# Predicted Sentiment: NEGATIVE
#
# Original Comment: eaisa khushi jisme rona aa raha he eaise khushi ke liye mujhe roj rona manjur he
# Cleaned Comment: eaisa khushi jisme rona aa raha he eaise khushi ke liye mujhe roj rona manjur he
# Predicted Sentiment: NEGATIVE
#
# Original Comment: all eyes in tears raw emotion staggering
# Cleaned Comment: all eyes in tears raw emotion staggering
# Predicted Sentiment: NEGATIVE
#
# Original Comment: allah wale harane ki ibadat kar rahe their
# Cleaned Comment: allah wale harane ki ibadat kar rahe their
# Predicted Sentiment: NEGATIVE
#
# Original Comment: well played team india ab to khushi ke aashu aaye yarrr
# Cleaned Comment: well played team india ab to khushi ke aashu aaye yarrr
# Predicted Sentiment: POSITIVE
#
# Original Comment: sir ji catch n vo hmari jaan hai
# Cleaned Comment: sir ji catch n vo hmari jaan hai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: har kar jitne bale team ko india kahte hai i love india
# Cleaned Comment: har kar jitne bale team ko india kahte hai i love india
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulations to whole india khushi ke aasu aa gye bhai
# Cleaned Comment: congratulations to whole india khushi ke aasu aa gye bhai
# Predicted Sentiment: POSITIVE
#
# Original Comment: bhenchooooood jeeet gayyye let the tears come out cause we deserve this tears of happiness
# Cleaned Comment: bhenchooooood jeeet gayyye let the tears come out cause we deserve this tears of happiness
# Predicted Sentiment: POSITIVE
#
# Original Comment: rohit sahab aur kohli sahab hmesha khelte rhe
# Cleaned Comment: rohit sahab aur kohli sahab hmesha khelte rhe
# Predicted Sentiment: POSITIVE
#
# Original Comment: history has been created by the the legend quotrohit sharmaquot
# Cleaned Comment: history has been created by the the legend quotrohit sharmaquot
# Predicted Sentiment: POSITIVE
#
# Original Comment: aj india wale mucher ne mach jeeta diya congrats
# Cleaned Comment: aj india wale mucher ne mach jeeta diya congrats
# Predicted Sentiment: NEGATIVE
#
# Original Comment: respect our bowler
# Cleaned Comment: respect our bowler
# Predicted Sentiment: POSITIVE
#
# Original Comment: boom boom bumrah and hardik pandya
# Cleaned Comment: boom boom bumrah and hardik pandya
# Predicted Sentiment: POSITIVE
#
# Original Comment: only king kohli i love virat kohli
# Cleaned Comment: only king kohli i love virat kohli
# Predicted Sentiment: POSITIVE
#
# Original Comment: sayad surya ka catch match me wapsi le aya bating me na sahi but ek catch ne match fever me la diya
# Cleaned Comment: sayad surya ka catch match me wapsi le aya bating me na sahi but ek catch ne match fever me la diya
# Predicted Sentiment: NEGATIVE
#
# Original Comment: haari aui match jeet gaya indiawell played guys congratulations
# Cleaned Comment: haari aui match jeet gaya indiawell played guys congratulations
# Predicted Sentiment: POSITIVE
#
# Original Comment: jai mata di
# Cleaned Comment: jai mata di
# Predicted Sentiment: NEGATIVE
#
# Original Comment: hardik ko bhi thanku bolna bhai logo jo use troll kar rahe thai
# Cleaned Comment: hardik ko bhi thanku bolna bhai logo jo use troll kar rahe thai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: respect button for rohit sharma nd team india
# Cleaned Comment: respect button for rohit sharma nd team india
# Predicted Sentiment: POSITIVE
#
# Original Comment: like from borivali
# Cleaned Comment: like from borivali
# Predicted Sentiment: POSITIVE
#
# Original Comment: i am very happy from nepal
# Cleaned Comment: i am very happy from nepal
# Predicted Sentiment: POSITIVE
#
# Original Comment: sorry hardik bhai for ipl tusi great ho goat hardik pandey
# Cleaned Comment: sorry hardik bhai for ipl tusi great ho goat hardik pandey
# Predicted Sentiment: NEGATIVE
#
# Original Comment: rohit rohit rohit
# Cleaned Comment: rohit rohit rohit
# Predicted Sentiment: NEGATIVE
#
# Original Comment: congratulations india winner
# Cleaned Comment: congratulations india winner
# Predicted Sentiment: POSITIVE
#
# Original Comment: panauti gaya world kab aaya modi gaya world cup aaya
# Cleaned Comment: panauti gaya world kab aaya modi gaya world cup aaya
# Predicted Sentiment: POSITIVE
#
# Original Comment: hum jeet gay
# Cleaned Comment: hum jeet gay
# Predicted Sentiment: NEGATIVE
#
# Original Comment: finally mummys ka aashirwad kaam aaya
# Cleaned Comment: finally mummys ka aashirwad kaam aaya
# Predicted Sentiment: POSITIVE
#
# Original Comment: mujhe pura biswas tha rohit captain hai wo kisi na kisi ko dega ball humjitenge jit gye
# Cleaned Comment: mujhe pura biswas tha rohit captain hai wo kisi na kisi ko dega ball humjitenge jit gye
# Predicted Sentiment: NEGATIVE
#
# Original Comment: congrats padoosi from nepal
# Cleaned Comment: congrats padoosi from nepal
# Predicted Sentiment: NEGATIVE
#
# Original Comment: rohit sharma fans come here and like for my champion captain rohit
# Cleaned Comment: rohit sharma fans come here and like for my champion captain rohit
# Predicted Sentiment: POSITIVE
#
# Original Comment: mera aansu gira
# Cleaned Comment: mera aansu gira
# Predicted Sentiment: POSITIVE
#
# Original Comment: real champions fast bowler and that surya catch which turn the match
# Cleaned Comment: real champions fast bowler and that surya catch which turn the match
# Predicted Sentiment: POSITIVE
#
# Original Comment: i dont believe anyone i believe in mahadev
# Cleaned Comment: i dont believe anyone i believe in mahadev
# Predicted Sentiment: NEGATIVE
#
# Original Comment: rohithardik bumrahkohli surya sardar all heroes salute to all indians team
# Cleaned Comment: rohithardik bumrahkohli surya sardar all heroes salute to all indians team
# Predicted Sentiment: POSITIVE
#
# Original Comment: bhai aaj kon kiska fan hr usse fark nhi padta is jit me puri india team ka full effort he
# Cleaned Comment: bhai aaj kon kiska fan hr usse fark nhi padta is jit me puri india team ka full effort he
# Predicted Sentiment: NEGATIVE
#
# Original Comment: rahul dravid finally lift that cup
# Cleaned Comment: rahul dravid finally lift that cup
# Predicted Sentiment: POSITIVE
#
# Original Comment: allhah ne meri dua qabool ki
# Cleaned Comment: allhah ne meri dua qabool ki
# Predicted Sentiment: NEGATIVE
#
# Original Comment: mai aapke charn vndna krta hu surya bhai mai bhai ye match south africa se dekh rha hu aapne hart attack se bcha diya you are a god for me
# Cleaned Comment: mai aapke charn vndna krta hu surya bhai mai bhai ye match south africa se dekh rha hu aapne hart attack se bcha diya you are a god for me
# Predicted Sentiment: NEGATIVE
#
# Original Comment: ham jit gaye sir thanks for tim india
# Cleaned Comment: ham jit gaye sir thanks for tim india
# Predicted Sentiment: POSITIVE
#
# Original Comment: one like for zakhmi sher hardik pandiya or baki sab ke liyeye khushi cant explain
# Cleaned Comment: one like for zakhmi sher hardik pandiya or baki sab ke liyeye khushi cant explain
# Predicted Sentiment: NEUTRAL
#
# Original Comment: hitman ki trophy bharat mata ki jay
# Cleaned Comment: hitman ki trophy bharat mata ki jay
# Predicted Sentiment: POSITIVE
#
# Original Comment: aaj to rula hi diya bhai love you team india
# Cleaned Comment: aaj to rula hi diya bhai love you team india
# Predicted Sentiment: POSITIVE
#
# Original Comment: power off india
# Cleaned Comment: power off india
# Predicted Sentiment: POSITIVE
#
# Original Comment: only hitman forever
# Cleaned Comment: only hitman forever
# Predicted Sentiment: POSITIVE
#
# Original Comment: agar fixing nhi hota to india me cupo ki line lagi hoti congratulations team india
# Cleaned Comment: agar fixing nhi hota to india me cupo ki line lagi hoti congratulations team india
# Predicted Sentiment: NEGATIVE
#
# Original Comment: ro hitman
# Cleaned Comment: ro hitman
# Predicted Sentiment: POSITIVE
#
# Original Comment: mee aaj bahut rooya tha kasam se
# Cleaned Comment: mee aaj bahut rooya tha kasam se
# Predicted Sentiment: POSITIVE
#
# Original Comment: terning point classen wicket tha bhai real tha
# Cleaned Comment: terning point classen wicket tha bhai real tha
# Predicted Sentiment: POSITIVE
#
# Original Comment: agar iss baar bhi haar jaate to main cricket dekhna band kar deta congratulations everyone
# Cleaned Comment: agar iss baar bhi haar jaate to main cricket dekhna band kar deta congratulations everyone
# Predicted Sentiment: NEGATIVE
#
# Original Comment: hardik hardik
# Cleaned Comment: hardik hardik
# Predicted Sentiment: NEGATIVE
#
# Original Comment: k fan h
# Cleaned Comment: k fan h
# Predicted Sentiment: NEUTRAL
#
# Original Comment: jio mere desh ka lal
# Cleaned Comment: jio mere desh ka lal
# Predicted Sentiment: NEUTRAL
#
# Original Comment: all player and all are champion
# Cleaned Comment: all player and all are champion
# Predicted Sentiment: POSITIVE
#
# Original Comment: yes we win finally
# Cleaned Comment: yes we win finally
# Predicted Sentiment: POSITIVE
#
# Original Comment: i love king kohli
# Cleaned Comment: i love king kohli
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulations thanku team india for giving this beautiful proud moment thanku
# Cleaned Comment: congratulations thanku team india for giving this beautiful proud moment thanku
# Predicted Sentiment: POSITIVE
#
# Original Comment: amazing final both teams played well
# Cleaned Comment: amazing final both teams played well
# Predicted Sentiment: POSITIVE
#
# Original Comment: hardik ka bura time tha tab tum jaise media aise players ko demotivate karthe the
# Cleaned Comment: hardik ka bura time tha tab tum jaise media aise players ko demotivate karthe the
# Predicted Sentiment: NEGATIVE
#
# Original Comment: both rohit and hardik were sad in ipl but they both are happy in india
# Cleaned Comment: both rohit and hardik were sad in ipl but they both are happy in india
# Predicted Sentiment: POSITIVE
#
# Original Comment: ak bar dar gaya tha
# Cleaned Comment: ak bar dar gaya tha
# Predicted Sentiment: POSITIVE
#
# Original Comment: we loose if kalasen wickets is not taken by the hardik
# Cleaned Comment: we loose if kalasen wickets is not taken by the hardik
# Predicted Sentiment: NEGATIVE
#
# Original Comment: bharat jita to lga mera sara sapna pura ho gya
# Cleaned Comment: bharat jita to lga mera sara sapna pura ho gya
# Predicted Sentiment: NEUTRAL
#
# Original Comment: hara huaa mach kaise jita jata hai koe hardik se jano
# Cleaned Comment: hara huaa mach kaise jita jata hai koe hardik se jano
# Predicted Sentiment: NEGATIVE
#
# Original Comment: hardik pandey real hero
# Cleaned Comment: hardik pandey real hero
# Predicted Sentiment: POSITIVE
#
# Original Comment: wow kiya game tha
# Cleaned Comment: wow kiya game tha
# Predicted Sentiment: POSITIVE
#
# Original Comment: whole team effort hardik bhaijab maine socha ki kya hardik aaj tum kar skte ho he did itwow fantastic brooo love my team love my whole india
# Cleaned Comment: whole team effort hardik bhaijab maine socha ki kya hardik aaj tum kar skte ho he did itwow fantastic brooo love my team love my whole india
# Predicted Sentiment: POSITIVE
#
# Original Comment: sky surya bhau
# Cleaned Comment: sky surya bhau
# Predicted Sentiment: POSITIVE
#
# Original Comment: apne abh tak nahi bola asue tapatap gir rhi hai india
# Cleaned Comment: apne abh tak nahi bola asue tapatap gir rhi hai india
# Predicted Sentiment: NEGATIVE
#
# Original Comment: bhai sach me rona aa gya tha
# Cleaned Comment: bhai sach me rona aa gya tha
# Predicted Sentiment: NEUTRAL
#
# Original Comment: king kohli retairmwnt
# Cleaned Comment: king kohli retairmwnt
# Predicted Sentiment: NEGATIVE
#
# Original Comment: modi gaya world cup aaya
# Cleaned Comment: modi gaya world cup aaya
# Predicted Sentiment: POSITIVE
#
# Original Comment: abb jeet ki suruat hogya hai
# Cleaned Comment: abb jeet ki suruat hogya hai
# Predicted Sentiment: NEUTRAL
#
# Original Comment: jetleyasurya love yousurya sa lam
# Cleaned Comment: jetleyasurya love yousurya sa lam
# Predicted Sentiment: NEUTRAL
#
# Original Comment: congratulations team india big fan of team india from bhutan
# Cleaned Comment: congratulations team india big fan of team india from bhutan
# Predicted Sentiment: POSITIVE
#
# Original Comment: i love you india sky wow
# Cleaned Comment: i love you india sky wow
# Predicted Sentiment: POSITIVE
#
# Original Comment: mere khusi ke aanso hai mera bharat mahaan
# Cleaned Comment: mere khusi ke aanso hai mera bharat mahaan
# Predicted Sentiment: POSITIVE
#
# Original Comment: for rohit
# Cleaned Comment: for rohit
# Predicted Sentiment: POSITIVE
#
# Original Comment: kis kis ne rohit and virat ka fan hogay congratulations team india
# Cleaned Comment: kis kis ne rohit and virat ka fan hogay congratulations team india
# Predicted Sentiment: NEGATIVE
#
# Original Comment: we are indians sir
# Cleaned Comment: we are indians sir
# Predicted Sentiment: POSITIVE
#
# Original Comment: bumrah amp hardik bowlings and match turning points surya catches what a catch yaar well done surya catch nahi hoti to sayad india wcup haar bhi sakti thi kyunki miller tha strike pe
# Cleaned Comment: bumrah amp hardik bowlings and match turning points surya catches what a catch yaar well done surya catch nahi hoti to sayad india wcup haar bhi sakti thi kyunki miller tha strike pe
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulation team india we won
# Cleaned Comment: congratulation team india we won
# Predicted Sentiment: NEGATIVE
#
# Original Comment: sab shivam dubey ki inning bhul gye
# Cleaned Comment: sab shivam dubey ki inning bhul gye
# Predicted Sentiment: NEGATIVE
#
# Original Comment: sorry sir im confused world cup jeetne ke khushi manao ya virat kohli ke retirement ka gham
# Cleaned Comment: sorry sir im confused world cup jeetne ke khushi manao ya virat kohli ke retirement ka gham
# Predicted Sentiment: NEGATIVE
#
# Original Comment: lv u india
# Cleaned Comment: lv u india
# Predicted Sentiment: POSITIVE
#
# Original Comment: bhai virat kohli virat kyu hai aaj pata chal gaya yaar
# Cleaned Comment: bhai virat kohli virat kyu hai aaj pata chal gaya yaar
# Predicted Sentiment: NEGATIVE
#
# Original Comment: proud of india king kohli always king
# Cleaned Comment: proud of india king kohli always king
# Predicted Sentiment: POSITIVE
#
# Original Comment: thank you sir love you aapka session dekh kar pura world dekh liya
# Cleaned Comment: thank you sir love you aapka session dekh kar pura world dekh liya
# Predicted Sentiment: POSITIVE
#
# Original Comment: thanks to boom boom
# Cleaned Comment: thanks to boom boom
# Predicted Sentiment: POSITIVE
#
# Original Comment: jit gye sir
# Cleaned Comment: jit gye sir
# Predicted Sentiment: NEUTRAL
#
# Original Comment: my comment was right regarding dube
# Cleaned Comment: my comment was right regarding dube
# Predicted Sentiment: POSITIVE
#
# Original Comment: india need a player like virat in upcoming days who can absorb the pressure and can handle a situation with a big knock in such pressure situationhe had shown many times and again today but yah at last final compilation of a teams work was excellent and team india has done the job
# Cleaned Comment: india need a player like virat in upcoming days who can absorb the pressure and can handle a situation with a big knock in such pressure situationhe had shown many times and again today but yah at last final compilation of a teams work was excellent and team india has done the job
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulations team india love you team india
# Cleaned Comment: congratulations team india love you team india
# Predicted Sentiment: POSITIVE
#
# Original Comment: goosebumps moment jai hind
# Cleaned Comment: goosebumps moment jai hind
# Predicted Sentiment: NEUTRAL
#
# Original Comment: ab time h hardik ko troll krne vle usko soryy trend kre dil bada dilhao
# Cleaned Comment: ab time h hardik ko troll krne vle usko soryy trend kre dil bada dilhao
# Predicted Sentiment: NEGATIVE
#
# Original Comment: evryones in this team are champions
# Cleaned Comment: evryones in this team are champions
# Predicted Sentiment: POSITIVE
#
# Original Comment: surya bhai jai shree ram
# Cleaned Comment: surya bhai jai shree ram
# Predicted Sentiment: NEUTRAL
#
# Original Comment: mujhe ek sawal hai har ek har video me apne comment ke liye bhik kyou mangta hauli
# Cleaned Comment: mujhe ek sawal hai har ek har video me apne comment ke liye bhik kyou mangta hauli
# Predicted Sentiment: NEGATIVE
#
# Original Comment: rohit sharma love u
# Cleaned Comment: rohit sharma love u
# Predicted Sentiment: POSITIVE
#
# Original Comment: virat ko retaired nahni lenaa chahiye thaa i dont believe
# Cleaned Comment: virat ko retaired nahni lenaa chahiye thaa i dont believe
# Predicted Sentiment: NEGATIVE
#
# Original Comment: finally after a long time our patience paid off thank you dear team india and many many many congratulations
# Cleaned Comment: finally after a long time our patience paid off thank you dear team india and many many many congratulations
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulations india from afghanistan
# Cleaned Comment: congratulations india from afghanistan
# Predicted Sentiment: POSITIVE
#
# Original Comment: thanks team india
# Cleaned Comment: thanks team india
# Predicted Sentiment: POSITIVE
#
# Original Comment: lagta hai blezzer ke niche apne pant nehi pehna
# Cleaned Comment: lagta hai blezzer ke niche apne pant nehi pehna
# Predicted Sentiment: NEGATIVE
#
# Original Comment: surya catch was the turning point
# Cleaned Comment: surya catch was the turning point
# Predicted Sentiment: POSITIVE
#
# Original Comment: finaly
# Cleaned Comment: finaly
# Predicted Sentiment: POSITIVE
#
# Original Comment: rohit love you
# Cleaned Comment: rohit love you
# Predicted Sentiment: POSITIVE
#
# Original Comment: lots of love from assam guwahatikharupetia
# Cleaned Comment: lots of love from assam guwahatikharupetia
# Predicted Sentiment: POSITIVE
#
# Original Comment: sir ji i have dont have words
# Cleaned Comment: sir ji i have dont have words
# Predicted Sentiment: POSITIVE
#
# Original Comment: kaun kaun manta hai bumrah duniya ke best bowler hai
# Cleaned Comment: kaun kaun manta hai bumrah duniya ke best bowler hai
# Predicted Sentiment: POSITIVE
#
# Original Comment: i am also crying
# Cleaned Comment: i am also crying
# Predicted Sentiment: POSITIVE
#
# Original Comment: abhi virat kohli aur rohit sharma ko ek aur world cup khelna hoga abhi wo nhi ke sakte
# Cleaned Comment: abhi virat kohli aur rohit sharma ko ek aur world cup khelna hoga abhi wo nhi ke sakte
# Predicted Sentiment: NEGATIVE
#
# Original Comment: kon kon rone laaga tha boss
# Cleaned Comment: kon kon rone laaga tha boss
# Predicted Sentiment: NEUTRAL
#
# Original Comment: klaseen mahadanav hai almost ind ko kha gaya tha
# Cleaned Comment: klaseen mahadanav hai almost ind ko kha gaya tha
# Predicted Sentiment: NEUTRAL
#
# Original Comment: virat ko miss krunga yr
# Cleaned Comment: virat ko miss krunga yr
# Predicted Sentiment: NEGATIVE
#
# Original Comment: viral hoga comment karo fast
# Cleaned Comment: viral hoga comment karo fast
# Predicted Sentiment: NEGATIVE
#
# Original Comment: sabse crucial over hardik and bumrah and wo surya ka catch
# Cleaned Comment: sabse crucial over hardik and bumrah and wo surya ka catch
# Predicted Sentiment: POSITIVE
#
# Original Comment: hardik ne nahi dhoka diya lekin rohit ne dhoka diya tha ipl me true man hardik
# Cleaned Comment: hardik ne nahi dhoka diya lekin rohit ne dhoka diya tha ipl me true man hardik
# Predicted Sentiment: NEGATIVE
#
# Original Comment: logo ne hardik ko boo kiya tha aaj hamare hardik ne logo ke boo ne match jitaya hai thanks hardik sir love you you are all of us hero
# Cleaned Comment: logo ne hardik ko boo kiya tha aaj hamare hardik ne logo ke boo ne match jitaya hai thanks hardik sir love you you are all of us hero
# Predicted Sentiment: NEGATIVE
#
# Original Comment: what a finall
# Cleaned Comment: what a finall
# Predicted Sentiment: POSITIVE
#
# Original Comment: well done india dil se team india
# Cleaned Comment: well done india dil se team india
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulations my champion team indialots of love all of you from depth of my heart
# Cleaned Comment: congratulations my champion team indialots of love all of you from depth of my heart
# Predicted Sentiment: POSITIVE
#
# Original Comment: what a match welldone team india
# Cleaned Comment: what a match welldone team india
# Predicted Sentiment: POSITIVE
#
# Original Comment: my heart h rohit sharma meri jaan h
# Cleaned Comment: my heart h rohit sharma meri jaan h
# Predicted Sentiment: POSITIVE
#
# Original Comment: i love my india we are champion
# Cleaned Comment: i love my india we are champion
# Predicted Sentiment: POSITIVE
#
# Original Comment: rohit sharma dil h jaan h
# Cleaned Comment: rohit sharma dil h jaan h
# Predicted Sentiment: NEUTRAL
#
# Original Comment: this trophy brings in us many tears we were waiting for long time and after ms we missed many trophies even got very close to itthanks to viratrohithardikbumraharshdeep u did it today
# Cleaned Comment: this trophy brings in us many tears we were waiting for long time and after ms we missed many trophies even got very close to itthanks to viratrohithardikbumraharshdeep u did it today
# Predicted Sentiment: POSITIVE
#
# Original Comment: hm jeet gye saheb
# Cleaned Comment: hm jeet gye saheb
# Predicted Sentiment: NEUTRAL
#
# Original Comment: i eventually used to drink country alcohol but today i gone with rs not royal stag but its rohit sharma
# Cleaned Comment: i eventually used to drink country alcohol but today i gone with rs not royal stag but its rohit sharma
# Predicted Sentiment: NEGATIVE
#
# Original Comment: hardik ko sabse jyada sir apne hi troll kiya tha but usne sbko bolti bnd kr di
# Cleaned Comment: hardik ko sabse jyada sir apne hi troll kiya tha but usne sbko bolti bnd kr di
# Predicted Sentiment: NEUTRAL
#
# Original Comment: rohi rat has done it
# Cleaned Comment: rohi rat has done it
# Predicted Sentiment: POSITIVE
#
# Original Comment: bhid me bhi virano ke saharethe great virat kohli
# Cleaned Comment: bhid me bhi virano ke saharethe great virat kohli
# Predicted Sentiment: POSITIVE
#
# Original Comment: kohli fan like
# Cleaned Comment: kohli fan like
# Predicted Sentiment: POSITIVE
#
# Original Comment: respect for team india button
# Cleaned Comment: respect for team india button
# Predicted Sentiment: POSITIVE
#
# Original Comment: saari india khus haibas dhoni naakhus hai
# Cleaned Comment: saari india khus haibas dhoni naakhus hai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: congratulations sir aaj bahut roya hu bhagwan se vinti kiya aur chamatkar bhi dekha om namah shivay
# Cleaned Comment: congratulations sir aaj bahut roya hu bhagwan se vinti kiya aur chamatkar bhi dekha om namah shivay
# Predicted Sentiment: NEGATIVE
#
# Original Comment: respect button for hardik sir and bumrah sir and surya sir in pressure
# Cleaned Comment: respect button for hardik sir and bumrah sir and surya sir in pressure
# Predicted Sentiment: POSITIVE
#
# Original Comment: bhai dua mangne pad gaye her ball pe besmellah besmellah karra tha or harthik or bumrah or arshdeep ke hatho uper wale ne humlogo ko jeetwa diya or surya wow catch thank god
# Cleaned Comment: bhai dua mangne pad gaye her ball pe besmellah besmellah karra tha or harthik or bumrah or arshdeep ke hatho uper wale ne humlogo ko jeetwa diya or surya wow catch thank god
# Predicted Sentiment: NEGATIVE
#
# Original Comment: congratulation indiafrom nepal
# Cleaned Comment: congratulation indiafrom nepal
# Predicted Sentiment: POSITIVE
#
# Original Comment: dil se puri teem ko hardik badhai i love my india
# Cleaned Comment: dil se puri teem ko hardik badhai i love my india
# Predicted Sentiment: POSITIVE
#
# Original Comment: ye woh banda hai jo ipl main hardik ko gali deta thaaj aj
# Cleaned Comment: ye woh banda hai jo ipl main hardik ko gali deta thaaj aj
# Predicted Sentiment: NEGATIVE
#
# Original Comment: rohit sharma love youuu man
# Cleaned Comment: rohit sharma love youuu man
# Predicted Sentiment: POSITIVE
#
# Original Comment: catch of match surya kamaal yadaw
# Cleaned Comment: catch of match surya kamaal yadaw
# Predicted Sentiment: POSITIVE
#
# Original Comment: the legend never endingwe are proud indian team
# Cleaned Comment: the legend never endingwe are proud indian team
# Predicted Sentiment: POSITIVE
#
# Original Comment: only king kohli
# Cleaned Comment: only king kohli
# Predicted Sentiment: NEGATIVE
#
# Original Comment: whole pakistan crying in the corner
# Cleaned Comment: whole pakistan crying in the corner
# Predicted Sentiment: NEGATIVE
#
# Original Comment: hindustan zinda bad
# Cleaned Comment: hindustan zinda bad
# Predicted Sentiment: NEGATIVE
#
# Original Comment: congratulations indian brother and sister bharat mata ki jay ho
# Cleaned Comment: congratulations indian brother and sister bharat mata ki jay ho
# Predicted Sentiment: POSITIVE
#
# Original Comment: aaj virat ki pari bhi achi thi sb india jaldi wicket gir gye the
# Cleaned Comment: aaj virat ki pari bhi achi thi sb india jaldi wicket gir gye the
# Predicted Sentiment: NEGATIVE
#
# Original Comment: app bhi thora rolo bhaiaj roko mat bohot bohot emotional moment hai
# Cleaned Comment: app bhi thora rolo bhaiaj roko mat bohot bohot emotional moment hai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: bhai ab kal se news pe focus kr lena pls india needs a good journalist
# Cleaned Comment: bhai ab kal se news pe focus kr lena pls india needs a good journalist
# Predicted Sentiment: NEUTRAL
#
# Original Comment: ilove my india cricket team
# Cleaned Comment: ilove my india cricket team
# Predicted Sentiment: POSITIVE
#
# Original Comment: we are miss you virat and rohit bhai we are remember on our memorable
# Cleaned Comment: we are miss you virat and rohit bhai we are remember on our memorable
# Predicted Sentiment: POSITIVE
#
# Original Comment: kyoki es bar hardik tha ha wahi hardik jisko tumne pure ipl me paresan kar diya
# Cleaned Comment: kyoki es bar hardik tha ha wahi hardik jisko tumne pure ipl me paresan kar diya
# Predicted Sentiment: NEGATIVE
#
# Original Comment: bhai dubey ko gali de rahe the usne bhi achha khela
# Cleaned Comment: bhai dubey ko gali de rahe the usne bhi achha khela
# Predicted Sentiment: NEGATIVE
#
# Original Comment: i love ms dhoni
# Cleaned Comment: i love ms dhoni
# Predicted Sentiment: POSITIVE
#
# Original Comment: saare jaha se acha hindustan hamara i love india team
# Cleaned Comment: saare jaha se acha hindustan hamara i love india team
# Predicted Sentiment: POSITIVE
#
# Original Comment: if india can won this match then i can do anything in my life no matters how hard will be situation
# Cleaned Comment: if india can won this match then i can do anything in my life no matters how hard will be situation
# Predicted Sentiment: POSITIVE
#
# Original Comment: sir ji apko dubey se kya problem hai
# Cleaned Comment: sir ji apko dubey se kya problem hai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: rohit and company
# Cleaned Comment: rohit and company
# Predicted Sentiment: POSITIVE
#
# Original Comment: india winnwhat a matchuffff finallywhat a catch skyyyyall r played awesomeampfantastic
# Cleaned Comment: india winnwhat a matchuffff finallywhat a catch skyyyyall r played awesomeampfantastic
# Predicted Sentiment: POSITIVE
#
# Original Comment: like for surya catch
# Cleaned Comment: like for surya catch
# Predicted Sentiment: POSITIVE
#
# Original Comment: end virat era but win world cup
# Cleaned Comment: end virat era but win world cup
# Predicted Sentiment: NEUTRAL
#
# Original Comment: sorry sir but i believe mahendra singh dhoni is the best captain forever
# Cleaned Comment: sorry sir but i believe mahendra singh dhoni is the best captain forever
# Predicted Sentiment: POSITIVE
#
# Original Comment: proud moment sir
# Cleaned Comment: proud moment sir
# Predicted Sentiment: POSITIVE
#
# Original Comment: south africa ke writing ke char over bacche the tab maine match dekhna shuru kiya tha tab to mujhe lag raha tha africa jeet jayegi fir maine bhagwan ka naam lena shuru kiya harbola bhagwan ji bata do jita do aur bhagwan ji ne jita diya jay siyaram
# Cleaned Comment: south africa ke writing ke char over bacche the tab maine match dekhna shuru kiya tha tab to mujhe lag raha tha africa jeet jayegi fir maine bhagwan ka naam lena shuru kiya harbola bhagwan ji bata do jita do aur bhagwan ji ne jita diya jay siyaram
# Predicted Sentiment: NEGATIVE
#
# Original Comment: shakti h hmare baram baba maharaj me
# Cleaned Comment: shakti h hmare baram baba maharaj me
# Predicted Sentiment: POSITIVE
#
# Original Comment: virat aur rohit ko gale lagte dekh ankh se ansu nikal gaye aur kaun hai jo roya ye scene dekhkar
# Cleaned Comment: virat aur rohit ko gale lagte dekh ankh se ansu nikal gaye aur kaun hai jo roya ye scene dekhkar
# Predicted Sentiment: NEGATIVE
#
# Original Comment: best duo king kohli and hitman
# Cleaned Comment: best duo king kohli and hitman
# Predicted Sentiment: POSITIVE
#
# Original Comment: klassen ka wicket turning point hardik pandya lazwab
# Cleaned Comment: klassen ka wicket turning point hardik pandya lazwab
# Predicted Sentiment: POSITIVE
#
# Original Comment: thank you rohit sharma and all indian team members
# Cleaned Comment: thank you rohit sharma and all indian team members
# Predicted Sentiment: POSITIVE
#
# Original Comment: hamkopuraumedtah
# Cleaned Comment: hamkopuraumedtah
# Predicted Sentiment: NEUTRAL
#
# Original Comment: rohit poori team k liye khela ms dhoni ki tra nai match hm b dekhte hai kon keya krta haiik world cup miss kiya hai ms dhoni ki vja se abhi tak yaad hai mujhekuj yaad aya ja nai
# Cleaned Comment: rohit poori team k liye khela ms dhoni ki tra nai match hm b dekhte hai kon keya krta haiik world cup miss kiya hai ms dhoni ki vja se abhi tak yaad hai mujhekuj yaad aya ja nai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: surya kumar catch
# Cleaned Comment: surya kumar catch
# Predicted Sentiment: POSITIVE
#
# Original Comment: yeh prathnao ka hi asar he definitely mene khud mehsoos kiya he ki prathna me bahut takat he
# Cleaned Comment: yeh prathnao ka hi asar he definitely mene khud mehsoos kiya he ki prathna me bahut takat he
# Predicted Sentiment: NEGATIVE
#
# Original Comment: rohit sharma good captain wonderful life
# Cleaned Comment: rohit sharma good captain wonderful life
# Predicted Sentiment: POSITIVE
#
# Original Comment: axar patel briliant
# Cleaned Comment: axar patel briliant
# Predicted Sentiment: POSITIVE
#
# Original Comment: miss u virat kohli
# Cleaned Comment: miss u virat kohli
# Predicted Sentiment: NEGATIVE
#
# Original Comment: love you indy
# Cleaned Comment: love you indy
# Predicted Sentiment: POSITIVE
#
# Original Comment: catch
# Cleaned Comment: catch
# Predicted Sentiment: POSITIVE
#
# Original Comment: rohit sharma ki capacity
# Cleaned Comment: rohit sharma ki capacity
# Predicted Sentiment: POSITIVE
#
# Original Comment: kon kon jasparit bhumrah ko legend manta ha
# Cleaned Comment: kon kon jasparit bhumrah ko legend manta ha
# Predicted Sentiment: POSITIVE
#
# Original Comment: excellent performance
# Cleaned Comment: excellent performance
# Predicted Sentiment: POSITIVE
#
# Original Comment: rohit is great man kohli is a real king bumra is unpredictable arshdeep is a hidden weapon sky is a superman hardik is a saver congratulations to team india what a match what a match win
# Cleaned Comment: rohit is great man kohli is a real king bumra is unpredictable arshdeep is a hidden weapon sky is a superman hardik is a saver congratulations to team india what a match what a match win
# Predicted Sentiment: POSITIVE
#
# Original Comment: ipl
# Cleaned Comment: ipl
# Predicted Sentiment: POSITIVE
#
# Original Comment: finally winajj sakoon ki neend
# Cleaned Comment: finally winajj sakoon ki neend
# Predicted Sentiment: POSITIVE
#
# Original Comment: god bless india
# Cleaned Comment: god bless india
# Predicted Sentiment: POSITIVE
#
# Original Comment: kis kisko lag raha hai ki hardik pandya ki wicket ke bad hindi mein badla hai
# Cleaned Comment: kis kisko lag raha hai ki hardik pandya ki wicket ke bad hindi mein badla hai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: virat kohli ritayrd
# Cleaned Comment: virat kohli ritayrd
# Predicted Sentiment: NEGATIVE
#
# Original Comment: kohli ko rota dekhkar bura lag raha tha yaar
# Cleaned Comment: kohli ko rota dekhkar bura lag raha tha yaar
# Predicted Sentiment: NEGATIVE
#
# Original Comment: bahut hi bakwaas or irritate kerta hain tu
# Cleaned Comment: bahut hi bakwaas or irritate kerta hain tu
# Predicted Sentiment: NEGATIVE
#
# Original Comment: dhakk dhakk tha bss aj
# Cleaned Comment: dhakk dhakk tha bss aj
# Predicted Sentiment: NEGATIVE
#
# Original Comment: o my god
# Cleaned Comment: o my god
# Predicted Sentiment: POSITIVE
#
# Original Comment: catch share karen naa
# Cleaned Comment: catch share karen naa
# Predicted Sentiment: POSITIVE
#
# Original Comment: sir ap v emotional ho geya aaj ka match dak kar jaan haat pe aageya tha
# Cleaned Comment: sir ap v emotional ho geya aaj ka match dak kar jaan haat pe aageya tha
# Predicted Sentiment: POSITIVE
#
# Original Comment: sa jita hua match haar gaya varna ham to rona shuru kar chuke the bumrah hardik or arshdip ke sath surya ka catch kabhi nahi bhulenge
# Cleaned Comment: sa jita hua match haar gaya varna ham to rona shuru kar chuke the bumrah hardik or arshdip ke sath surya ka catch kabhi nahi bhulenge
# Predicted Sentiment: NEGATIVE
#
# Original Comment: iam happy for team india but little disappointed for south africa also
# Cleaned Comment: iam happy for team india but little disappointed for south africa also
# Predicted Sentiment: POSITIVE
#
# Original Comment: surya good time cache
# Cleaned Comment: surya good time cache
# Predicted Sentiment: POSITIVE
#
# Original Comment: mere pitaji
# Cleaned Comment: mere pitaji
# Predicted Sentiment: NEUTRAL
#
# Original Comment: have cried cz couldnt control my emotions
# Cleaned Comment: have cried cz couldnt control my emotions
# Predicted Sentiment: NEGATIVE
#
# Original Comment: mujhe bhi boht rona aya aj
# Cleaned Comment: mujhe bhi boht rona aya aj
# Predicted Sentiment: NEGATIVE
#
# Original Comment: we are the chams now
# Cleaned Comment: we are the chams now
# Predicted Sentiment: POSITIVE
#
# Original Comment: ham bhi roye the
# Cleaned Comment: ham bhi roye the
# Predicted Sentiment: NEGATIVE
#
# Original Comment: dil se salute he bhai meri team india ko thanks
# Cleaned Comment: dil se salute he bhai meri team india ko thanks
# Predicted Sentiment: POSITIVE
#
# Original Comment: i love my all indian teams
# Cleaned Comment: i love my all indian teams
# Predicted Sentiment: POSITIVE
#
# Original Comment: i very very love you india criket team
# Cleaned Comment: i very very love you india criket team
# Predicted Sentiment: POSITIVE
#
# Original Comment: jay jagannath
# Cleaned Comment: jay jagannath
# Predicted Sentiment: POSITIVE
#
# Original Comment: sir ab sahi kaeh rahi hoi from india
# Cleaned Comment: sir ab sahi kaeh rahi hoi from india
# Predicted Sentiment: NEGATIVE
#
# Original Comment: hardik pandya man of the match
# Cleaned Comment: hardik pandya man of the match
# Predicted Sentiment: POSITIVE
#
# Original Comment: mera dil hath me agaya tha ek pal keliye phir wo surya ka catch
# Cleaned Comment: mera dil hath me agaya tha ek pal keliye phir wo surya ka catch
# Predicted Sentiment: NEGATIVE
#
# Original Comment: it is a team work that helped india to win this everyone did his job perfectly hard to give credit to any one person
# Cleaned Comment: it is a team work that helped india to win this everyone did his job perfectly hard to give credit to any one person
# Predicted Sentiment: POSITIVE
#
# Original Comment: sir mera abhi yahi dil kaha raha tha ki aaj india match har nahi sakti
# Cleaned Comment: sir mera abhi yahi dil kaha raha tha ki aaj india match har nahi sakti
# Predicted Sentiment: NEUTRAL
#
# Original Comment: i love india love shubanker mishra sir
# Cleaned Comment: i love india love shubanker mishra sir
# Predicted Sentiment: POSITIVE
#
# Original Comment: akshar patel all time best rohit sharma too good
# Cleaned Comment: akshar patel all time best rohit sharma too good
# Predicted Sentiment: POSITIVE
#
# Original Comment: sir ap itni garami mein coat pant pahan ke match dekh rhe the kya
# Cleaned Comment: sir ap itni garami mein coat pant pahan ke match dekh rhe the kya
# Predicted Sentiment: NEGATIVE
#
# Original Comment: heartiest congratulations and best wishes to the whole of india
# Cleaned Comment: heartiest congratulations and best wishes to the whole of india
# Predicted Sentiment: POSITIVE
#
# Original Comment: aap kya bole the virat kohli ke bare mein king always king
# Cleaned Comment: aap kya bole the virat kohli ke bare mein king always king
# Predicted Sentiment: POSITIVE
#
# Original Comment: actually if india lost virat inning will be wrong because of strike rate and hardik cant get to chances to finish with bat but he finish with the bowl i want the win of india thats why i am fear with virat inning and batting is not good from every batter but balling is superb from jasprit pandya and singh and in the last virat inning is also proved good and congratulations to all indians
# Cleaned Comment: actually if india lost virat inning will be wrong because of strike rate and hardik cant get to chances to finish with bat but he finish with the bowl i want the win of india thats why i am fear with virat inning and batting is not good from every batter but balling is superb from jasprit pandya and singh and in the last virat inning is also proved good and congratulations to all indians
# Predicted Sentiment: POSITIVE
#
# Original Comment: love you bhaiya ji
# Cleaned Comment: love you bhaiya ji
# Predicted Sentiment: POSITIVE
#
# Original Comment: i am from nepal ipl tol great player toll hardik my best player good job indian team
# Cleaned Comment: i am from nepal ipl tol great player toll hardik my best player good job indian team
# Predicted Sentiment: POSITIVE
#
# Original Comment: kyun ki haarke jeetna ko hi bazigar kehte hain
# Cleaned Comment: kyun ki haarke jeetna ko hi bazigar kehte hain
# Predicted Sentiment: NEGATIVE
#
# Original Comment: king kohli ke constancy pr kabhi sak nii karne ka
# Cleaned Comment: king kohli ke constancy pr kabhi sak nii karne ka
# Predicted Sentiment: NEGATIVE
#
# Original Comment: ro hit c
# Cleaned Comment: ro hit c
# Predicted Sentiment: NEGATIVE
#
# Original Comment: hardik pandya finishes in his own style
# Cleaned Comment: hardik pandya finishes in his own style
# Predicted Sentiment: POSITIVE
#
# Original Comment: i love ro hit sharma virat
# Cleaned Comment: i love ro hit sharma virat
# Predicted Sentiment: POSITIVE
#
# Original Comment: indian culture winar
# Cleaned Comment: indian culture winar
# Predicted Sentiment: POSITIVE
#
# Original Comment: nobaby can talk about virat retirementi feel the true legend of indian cricketthe virat kohli true legend virat kohli
# Cleaned Comment: nobaby can talk about virat retirementi feel the true legend of indian cricketthe virat kohli true legend virat kohli
# Predicted Sentiment: POSITIVE
#
# Original Comment: most suspense thriller movies most suspence thriller match
# Cleaned Comment: most suspense thriller movies most suspence thriller match
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulations india from pakistan we are happy you won our hearts this for you mishra sahib your biggest fan from pakistan
# Cleaned Comment: congratulations india from pakistan we are happy you won our hearts this for you mishra sahib your biggest fan from pakistan
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulations we have done itsir we proud of our team and specially proud of roko and bumrah hardik big big love for you unbelievable
# Cleaned Comment: congratulations we have done itsir we proud of our team and specially proud of roko and bumrah hardik big big love for you unbelievable
# Predicted Sentiment: POSITIVE
#
# Original Comment: happy for rohit and virat
# Cleaned Comment: happy for rohit and virat
# Predicted Sentiment: POSITIVE
#
# Original Comment: respect button for hardik sir and bumrah sir and surya sir
# Cleaned Comment: respect button for hardik sir and bumrah sir and surya sir
# Predicted Sentiment: POSITIVE
#
# Original Comment: indian pawar
# Cleaned Comment: indian pawar
# Predicted Sentiment: POSITIVE
#
# Original Comment: such an amazing come back lets gooo boom boom bhumrah well deserved team india
# Cleaned Comment: such an amazing come back lets gooo boom boom bhumrah well deserved team india
# Predicted Sentiment: POSITIVE
#
# Original Comment: today hardik pandya hero of the final
# Cleaned Comment: today hardik pandya hero of the final
# Predicted Sentiment: POSITIVE
#
# Original Comment: is pal ke gawah ham sabhi log haisolute for hit man
# Cleaned Comment: is pal ke gawah ham sabhi log haisolute for hit man
# Predicted Sentiment: NEUTRAL
#
# Original Comment: indian cricket team fans like here
# Cleaned Comment: indian cricket team fans like here
# ...
# Predicted Sentiment: POSITIVE
#
# Original Comment: koun koun subhankar ke video ka intajaar kr rha tha
# Cleaned Comment: koun koun subhankar ke video ka intajaar kr rha tha
# Predicted Sentiment: NEGATIVE
#
# Original Comment: love you rohit happy
# Cleaned Comment: love you rohit happy
# Predicted Sentiment: POSITIVE
#
# Original Comment: hardik bahut troll kiye the bro
# Cleaned Comment: hardik bahut troll kiye the bro
# Predicted Sentiment: NEUTRAL
#
# Original Comment: victory india
# Cleaned Comment: victory india
# Predicted Sentiment: POSITIVE
#
# Original Comment: wahi pandaya jo ipl me indian fan troll kiye hai wahi ajjj thrif kar rahe hai
# Cleaned Comment: wahi pandaya jo ipl me indian fan troll kiye hai wahi ajjj thrif kar rahe hai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: india jeet gayi
# Cleaned Comment: india jeet gayi
# Predicted Sentiment: NEGATIVE
#
# Original Comment: viralrohit india i am right comment viral kr do indians
# Cleaned Comment: viralrohit india i am right comment viral kr do indians
# Predicted Sentiment: NEGATIVE
#
# Original Comment: why virat kohli why yaar kohli ne sanyas le liya t twenty world cup se
# Cleaned Comment: why virat kohli why yaar kohli ne sanyas le liya t twenty world cup se
# Predicted Sentiment: NEGATIVE
#
# Original Comment: ab bolo be shubhakar dube ke bare me
# Cleaned Comment: ab bolo be shubhakar dube ke bare me
# Predicted Sentiment: NEGATIVE
#
# Original Comment: what a comeback king kohli
# Cleaned Comment: what a comeback king kohli
# Predicted Sentiment: POSITIVE
#
# Original Comment: i love india and rohit sharma
# Cleaned Comment: i love india and rohit sharma
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulations subhankar mishra brother
# Cleaned Comment: congratulations subhankar mishra brother
# Predicted Sentiment: POSITIVE
#
# Original Comment: king retired
# Cleaned Comment: king retired
# Predicted Sentiment: NEGATIVE
#
# Original Comment: surya kumar ka catch
# Cleaned Comment: surya kumar ka catch
# Predicted Sentiment: POSITIVE
#
# Original Comment: virat kohli and rohit sharma
# Cleaned Comment: virat kohli and rohit sharma
# Predicted Sentiment: POSITIVE
#
# Original Comment: virat retire bhai
# Cleaned Comment: virat retire bhai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: rohit sharma the best captain
# Cleaned Comment: rohit sharma the best captain
# Predicted Sentiment: POSITIVE
#
# Original Comment: hiridik ne match jita diya
# Cleaned Comment: hiridik ne match jita diya
# Predicted Sentiment: NEUTRAL
#
# Original Comment: virat rohit axar
# Cleaned Comment: virat rohit axar
# Predicted Sentiment: NEGATIVE
#
# Original Comment: thanks for reporting thanks for indian teams final kab hua vah bahut bahut mubarak jay hind jay sanvidhan
# Cleaned Comment: thanks for reporting thanks for indian teams final kab hua vah bahut bahut mubarak jay hind jay sanvidhan
# Predicted Sentiment: POSITIVE
#
# Original Comment: world se to khusi mili but ek dukh bhi deke gaya virat kohli ne
# Cleaned Comment: world se to khusi mili but ek dukh bhi deke gaya virat kohli ne
# Predicted Sentiment: NEGATIVE
#
# Original Comment: like this comment for india team
# Cleaned Comment: like this comment for india team
# Predicted Sentiment: POSITIVE
#
# Original Comment: shree radhe kishna
# Cleaned Comment: shree radhe kishna
# Predicted Sentiment: NEGATIVE
#
# Original Comment: rohit sir love you
# Cleaned Comment: rohit sir love you
# Predicted Sentiment: POSITIVE
#
# Original Comment: virat sir jaisa abhi current koi nhi hai thanks king kohli
# Cleaned Comment: virat sir jaisa abhi current koi nhi hai thanks king kohli
# Predicted Sentiment: POSITIVE
#
# Original Comment: best feeling this time
# Cleaned Comment: best feeling this time
# Predicted Sentiment: POSITIVE
#
# Original Comment: aap ko video ka intezar kar rahe the
# Cleaned Comment: aap ko video ka intezar kar rahe the
# Predicted Sentiment: NEGATIVE
#
# Original Comment: true
# Cleaned Comment: true
# Predicted Sentiment: POSITIVE
#
# Original Comment: respect button for team india
# Cleaned Comment: respect button for team india
# Predicted Sentiment: POSITIVE
#
# Original Comment: sir mai apka hi video ka wait kr raha tha besabri se
# Cleaned Comment: sir mai apka hi video ka wait kr raha tha besabri se
# Predicted Sentiment: NEGATIVE
#
# Original Comment: islam haar gya mubarak ho
# Cleaned Comment: islam haar gya mubarak ho
# Predicted Sentiment: POSITIVE
#
# Original Comment: hardik op
# Cleaned Comment: hardik op
# Predicted Sentiment: NEGATIVE
#
# Original Comment: love for indian team
# Cleaned Comment: love for indian team
# Predicted Sentiment: POSITIVE
#
# Original Comment: itni khushi etna sukoon jidagi main pehli baar mila hai
# Cleaned Comment: itni khushi etna sukoon jidagi main pehli baar mila hai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: maza aagya kasam se dil mai bahut dard ho raha tha
# Cleaned Comment: maza aagya kasam se dil mai bahut dard ho raha tha
# Predicted Sentiment: NEGATIVE
#
# Original Comment: aaj chhapri ne to kamal kar diya bhi
# Cleaned Comment: aaj chhapri ne to kamal kar diya bhi
# Predicted Sentiment: NEGATIVE
#
# Original Comment: khash hardik one day me bhi hota
# Cleaned Comment: khash hardik one day me bhi hota
# Predicted Sentiment: NEGATIVE
#
# Original Comment: bahut bahut badhaai ho aap sab ko
# Cleaned Comment: bahut bahut badhaai ho aap sab ko
# Predicted Sentiment: NEGATIVE
#
# Original Comment: finnally world cup win indian
# Cleaned Comment: finnally world cup win indian
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulations mai india love you india
# Cleaned Comment: congratulations mai india love you india
# Predicted Sentiment: POSITIVE
#
# Original Comment: i love india time
# Cleaned Comment: i love india time
# Predicted Sentiment: POSITIVE
#
# Original Comment: mi hardij thim india hardik
# Cleaned Comment: mi hardij thim india hardik
# Predicted Sentiment: NEGATIVE
#
# Original Comment: cricket ka sabse most moment kaun sa raha
# Cleaned Comment: cricket ka sabse most moment kaun sa raha
# Predicted Sentiment: NEUTRAL
#
# Original Comment: virat kohli fans like
# Cleaned Comment: virat kohli fans like
# Predicted Sentiment: POSITIVE
#
# Original Comment: love you rohit sir congratulations
# Cleaned Comment: love you rohit sir congratulations
# Predicted Sentiment: POSITIVE
#
# Original Comment: ek like
# Cleaned Comment: ek like
# Predicted Sentiment: POSITIVE
#
# Original Comment: tq team india
# Cleaned Comment: tq team india
# Predicted Sentiment: POSITIVE
#
# Original Comment: rohit sharma the legend
# Cleaned Comment: rohit sharma the legend
# Predicted Sentiment: POSITIVE
#
# Original Comment: ke se pehle mujhe aa gya tha sir me
# Cleaned Comment: ke se pehle mujhe aa gya tha sir me
# Predicted Sentiment: NEGATIVE
#
# Original Comment: love v rohit and virat bhai
# Cleaned Comment: love v rohit and virat bhai
# Predicted Sentiment: POSITIVE
#
# Original Comment: kingfu pandya
# Cleaned Comment: kingfu pandya
# Predicted Sentiment: POSITIVE
#
# Original Comment: rohit sharma legend
# Cleaned Comment: rohit sharma legend
# Predicted Sentiment: POSITIVE
#
# Original Comment: saare jahan se achha hindustan hamara
# Cleaned Comment: saare jahan se achha hindustan hamara
# Predicted Sentiment: NEGATIVE
#
# Original Comment: rosuper hitman
# Cleaned Comment: rosuper hitman
# Predicted Sentiment: POSITIVE
#
# Original Comment: kb se wait kr rhe the sir aappka video
# Cleaned Comment: kb se wait kr rhe the sir aappka video
# Predicted Sentiment: NEGATIVE
#
# Original Comment: congratulations bhiya aapko bhi
# Cleaned Comment: congratulations bhiya aapko bhi
# Predicted Sentiment: POSITIVE
#
# Original Comment: literally i am waiting for your video
# Cleaned Comment: literally i am waiting for your video
# Predicted Sentiment: NEGATIVE
#
# Original Comment: ind won
# Cleaned Comment: ind won
# Predicted Sentiment: NEUTRAL
#
# Original Comment: love from nepal always support indian team after nepal
# Cleaned Comment: love from nepal always support indian team after nepal
# Predicted Sentiment: POSITIVE
#
# Original Comment: finally we won congratulations india
# Cleaned Comment: finally we won congratulations india
# Predicted Sentiment: POSITIVE
#
# Original Comment: love you pandaya
# Cleaned Comment: love you pandaya
# Predicted Sentiment: POSITIVE
#
# Original Comment: virat take retired
# Cleaned Comment: virat take retired
# Predicted Sentiment: NEGATIVE
#
# Original Comment: catch ne match jeeta diya
# Cleaned Comment: catch ne match jeeta diya
# Predicted Sentiment: NEGATIVE
#
# Original Comment: sir we are champions
# Cleaned Comment: sir we are champions
# Predicted Sentiment: POSITIVE
#
# Original Comment: aap hi k wet kar raha tha aapko sun kar light off krunga
# Cleaned Comment: aap hi k wet kar raha tha aapko sun kar light off krunga
# Predicted Sentiment: NEGATIVE
#
# Original Comment: sir g kab se wait krre the
# Cleaned Comment: sir g kab se wait krre the
# Predicted Sentiment: NEGATIVE
#
# Original Comment: we finally won love you virat and hitman
# Cleaned Comment: we finally won love you virat and hitman
# Predicted Sentiment: POSITIVE
#
# Original Comment: team india played very well
# Cleaned Comment: team india played very well
# Predicted Sentiment: POSITIVE
#
# Original Comment: support him
# Cleaned Comment: support him
# Predicted Sentiment: POSITIVE
#
# Original Comment: tabhi se wait kiy aapke video ka
# Cleaned Comment: tabhi se wait kiy aapke video ka
# Predicted Sentiment: NEGATIVE
#
# Original Comment: kaun kaun roya tha match ke baad
# Cleaned Comment: kaun kaun roya tha match ke baad
# Predicted Sentiment: NEGATIVE
#
# Original Comment: bumrah bhai thank u tu nhi hota to aaj trophy bhi nhi hota
# Cleaned Comment: bumrah bhai thank u tu nhi hota to aaj trophy bhi nhi hota
# Predicted Sentiment: NEGATIVE
#
# Original Comment: kungfu pandya
# Cleaned Comment: kungfu pandya
# Predicted Sentiment: NEUTRAL
#
# Original Comment: king king inning
# Cleaned Comment: king king inning
# Predicted Sentiment: POSITIVE
#
# Original Comment: universe
# Cleaned Comment: universe
# Predicted Sentiment: POSITIVE
#
# Original Comment: i love ind
# Cleaned Comment: i love ind
# Predicted Sentiment: POSITIVE
#
# Original Comment: jay hind rohit sharma
# Cleaned Comment: jay hind rohit sharma
# Predicted Sentiment: POSITIVE
#
# Original Comment: respect button for indian team
# Cleaned Comment: respect button for indian team
# Predicted Sentiment: POSITIVE
#
# Original Comment: kis kis video ka intezar tha
# Cleaned Comment: kis kis video ka intezar tha
# Predicted Sentiment: POSITIVE
#
# Original Comment: india world cup win button
# Cleaned Comment: india world cup win button
# Predicted Sentiment: POSITIVE
#
# Original Comment: east or west our india is best
# Cleaned Comment: east or west our india is best
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulations all ind
# Cleaned Comment: congratulations all ind
# Predicted Sentiment: POSITIVE
#
# Original Comment: world championshipindia
# Cleaned Comment: world championshipindia
# Predicted Sentiment: POSITIVE
#
# Original Comment: respect button of hitman sharma
# Cleaned Comment: respect button of hitman sharma
# Predicted Sentiment: POSITIVE
#
# Original Comment: fast coment
# Cleaned Comment: fast coment
# Predicted Sentiment: POSITIVE
#
# Original Comment: legend virat kohli
# Cleaned Comment: legend virat kohli
# Predicted Sentiment: POSITIVE
#
# Original Comment: surya and hardik ka last kamal
# Cleaned Comment: surya and hardik ka last kamal
# Predicted Sentiment: POSITIVE
#
# Original Comment: thank you rohit sharma congratulations
# Cleaned Comment: thank you rohit sharma congratulations
# Predicted Sentiment: POSITIVE
#
# Original Comment: rohit ke fan channel ko subscribe kre
# Cleaned Comment: rohit ke fan channel ko subscribe kre
# Predicted Sentiment: NEGATIVE
#
# Original Comment: bhai hm jit to gye but virat sir ne retire le liya
# Cleaned Comment: bhai hm jit to gye but virat sir ne retire le liya
# Predicted Sentiment: NEGATIVE
#
# Original Comment: me apka vedio dekhne ka intejar ke rha tha
# Cleaned Comment: me apka vedio dekhne ka intejar ke rha tha
# Predicted Sentiment: NEGATIVE
#
# Original Comment: viral kohli respect button
# Cleaned Comment: viral kohli respect button
# Predicted Sentiment: NEGATIVE
#
# Original Comment: i my indea
# Cleaned Comment: i my indea
# Predicted Sentiment: POSITIVE
#
# Original Comment: india deserves this rohit and virat deserves this trophy
# Cleaned Comment: india deserves this rohit and virat deserves this trophy
# Predicted Sentiment: POSITIVE
#
# Original Comment: wow bhai shina tan hogaya
# Cleaned Comment: wow bhai shina tan hogaya
# Predicted Sentiment: POSITIVE
#
# Original Comment: king kohli ka strong comeback in final match
# Cleaned Comment: king kohli ka strong comeback in final match
# Predicted Sentiment: POSITIVE
#
# Original Comment: bolane aaya tha india world cup jeet ki
# Cleaned Comment: bolane aaya tha india world cup jeet ki
# Predicted Sentiment: NEUTRAL
#
# Original Comment: first comment like karo team india ke liye
# Cleaned Comment: first comment like karo team india ke liye
# Predicted Sentiment: NEGATIVE
#
# Original Comment: sar sawth afrika kha jita hai
# Cleaned Comment: sar sawth afrika kha jita hai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: respect button teamindia and rohit sharma like ka button tod dalo
# Cleaned Comment: respect button teamindia and rohit sharma like ka button tod dalo
# Predicted Sentiment: POSITIVE
#
# Original Comment: jay hind team india
# Cleaned Comment: jay hind team india
# Predicted Sentiment: NEUTRAL
#
# Original Comment: team india ke liye ek like
# Cleaned Comment: team india ke liye ek like
# Predicted Sentiment: POSITIVE
#
# Original Comment: virat kohli ke liye like krdo
# Cleaned Comment: virat kohli ke liye like krdo
# Predicted Sentiment: NEGATIVE
#
# Original Comment: one like for team india
# Cleaned Comment: one like for team india
# Predicted Sentiment: POSITIVE
#
# Original Comment: my fist comments
# Cleaned Comment: my fist comments
# Predicted Sentiment: POSITIVE
#
# Original Comment: kahate hain humko india wale
# Cleaned Comment: kahate hain humko india wale
# Predicted Sentiment: NEGATIVE
#
# Original Comment: ham jit gai
# Cleaned Comment: ham jit gai
# Predicted Sentiment: NEUTRAL
#
# Original Comment: india respects the baton
# Cleaned Comment: india respects the baton
# Predicted Sentiment: POSITIVE
#
# Original Comment: sir main aapka video ka wait kar raha tha
# Cleaned Comment: sir main aapka video ka wait kar raha tha
# Predicted Sentiment: NEGATIVE
#
# Original Comment: yes we are champion
# Cleaned Comment: yes we are champion
# Predicted Sentiment: POSITIVE
#
# Original Comment: rohit virat fan like button
# Cleaned Comment: rohit virat fan like button
# Predicted Sentiment: NEGATIVE
#
# Original Comment: joy hind
# Cleaned Comment: joy hind
# Predicted Sentiment: NEGATIVE
#
# Original Comment: mishra ji delay kr diya
# Cleaned Comment: mishra ji delay kr diya
# Predicted Sentiment: NEGATIVE
#
# Original Comment: ram ram bhai congratulations to all
# Cleaned Comment: ram ram bhai congratulations to all
# Predicted Sentiment: POSITIVE
#
# Original Comment: fast like
# Cleaned Comment: fast like
# Predicted Sentiment: NEUTRAL
#
# Original Comment: congratulations team india and supporters
# Cleaned Comment: congratulations team india and supporters
# Predicted Sentiment: POSITIVE
#
# Original Comment: nepal frist comment dekhte he kitna like milta hai
# Cleaned Comment: nepal frist comment dekhte he kitna like milta hai
# Predicted Sentiment: NEGATIVE
#
# Original Comment: frist like comment
# Cleaned Comment: frist like comment
# Predicted Sentiment: POSITIVE
#
# Original Comment: congratulation team india well done
# Cleaned Comment: congratulation team india well done
# Predicted Sentiment: POSITIVE
#
# Original Comment: ji sir
# Cleaned Comment: ji sir
# Predicted Sentiment: POSITIVE
#
# Original Comment: cack de india
# Cleaned Comment: cack de india
# Predicted Sentiment: NEUTRAL
#
# Original Comment: love you sarr
# Cleaned Comment: love you sarr
# Predicted Sentiment: POSITIVE
#
# Original Comment: virat is best
# Cleaned Comment: virat is best
# Predicted Sentiment: POSITIVE
#
# Original Comment: virat retire
# Cleaned Comment: virat retire
# Predicted Sentiment: NEGATIVE
#
# Original Comment: my first views
# Cleaned Comment: my first views
# Predicted Sentiment: POSITIVE
#
# Overall Sentiment of Comments:
# Negative: 35.57%
# Neutral: 11.84%
# Positive: 52.58%
# No ground truth labels found for accuracy calculation.

# %%
df_new.to_csv('/content/drive/MyDrive/Colab Notebooks/bert/bert_2/final_output_bert_set4', index=False)

df_new
# Out:
#                                          Cleaned_Comment Predicted_Sentiment
# 0                                         watching today            POSITIVE
# 1      sa donated the cup to india these sa players c...            NEGATIVE
# 2                                            i am crying            POSITIVE
# 3                      uff the commentary is at its best            POSITIVE
# 4                                          forever india            POSITIVE
# ...                                                  ...                 ...
# 14095                                      cack de india             NEUTRAL
# 14096                                      love you sarr            POSITIVE
# 14097                                      virat is best            POSITIVE
# 14098                                       virat retire            NEGATIVE
# 14099                                     my first views            POSITIVE
#
# [14100 rows x 2 columns]
